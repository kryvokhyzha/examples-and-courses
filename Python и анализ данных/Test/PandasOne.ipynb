# %%
import pandas as pd

# %%
frame = pd.DataFrame({'number':range(10), 'chars':['a']*10)

# %%
frame
# Out:
#    number chars
# 0       0     a
# 1       1     a
# 2       2     a
# 3       3     a
# 4       4     a
# 5       5     a
# 6       6     a
# 7       7     a
# 8       8     a
# 9       9     a

# %%
frame = pd.read_csv('data.tsv', sep='\t', header=0)

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер

# %%
frame.columns
# Out:
# Index(['Name', 'Birth', 'City', 'Position'], dtype='object')

# %%
frame.shape
# Out:
# (6, 4)

# %%
new_line = {'Name':'Roma', 'Birth':'11.10.1999', 'City':'Kiev'}

# %%
frame = frame.append(new_line, ignore_index=True)

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6             Roma  11.10.1999       Kiev       NaN

# %%
frame['newC'] = ['1']*7

# %%
frame
# Out:
#               Name       Birth       City  Position newC
# 0      Иванов А.А.  22.03.1980     Москва       NaN    1
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер    1
# 2       Белов М.М.  13.02.1980     Ростов  менеджер    1
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN    1
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер    1
# 5     Костров С.О.  31.05.1985     Москва    стажер    1
# 6             Roma  11.10.1999       Kiev       NaN    1

# %%
frame.drop('newC', axis=1, inplace=True)

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6             Roma  11.10.1999       Kiev       NaN

# %%
frame.drop([5,6], axis=0 ,inplace=True)

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер

# %%
frame.to_csv('new_data.csv', sep=',', header=True, index=None)
