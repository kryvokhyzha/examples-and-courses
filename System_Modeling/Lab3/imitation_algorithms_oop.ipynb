# %% [markdown]
# # Lab 3
# + ## Автор: Роман Кривохижа
# + ## Група: ІС-72
# + ## Викладач: Новікова П.А.

# %% [markdown]
# ****
# ****
# ****

# %% [markdown]
# ## Module importing

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
# %matplotlib inline

# %% [markdown]
# ## Algorithm implementation

# %% [markdown]
# + Алгоритм, який відтворює функціонування системи, за допомогою комп’ютерної програми називається **алгоритмом імітації**.
#
# + Вимоги на обслуговування генеруються елементом **CREATE** і відправляються на обслуговування до елементу **PROCESS**, який здійснює обслуговування з часовою затримкою, заданою випадковим числом, та обмеження на довжину черги, заданим невід’ємним числом
#
# + Імітація здійснюється за відомим з попередньої теми принципом: визначається момент найближчої події, просувається час в момент найближчої події та здійснюється відповідна подія.
#
# <font size="4">Ймовірність відмови: $P = \frac{N_{unserv}}{N_{all}}$</font>
#
# <font size="4">Середня довжина черги: $L_{aver} = \frac{\sum_{i} L_i \Delta t_i}{T_{mod}}$</font>
#
# <font size="4">Середній час очікування: $Q_{aver} = \frac{\sum_{i} L_i \Delta t_i}{N_{serv}}$</font>

# %% [markdown]
# <img src="diag.jpg">

# %%
class Rand:
    """
    Генерація випадкового числа за заданим законом розподілу
    """
    @staticmethod
    def exp(time_mean):
        a = 0
        while a == 0:
            a = np.random.rand()
        return -time_mean * np.log(a)
    
    @staticmethod
    def unif(time_min, time_max):
        a = 0
        while a == 0:
            a = np.random.rand()
        a = time_min + a * (time_max - time_min)
        return a
    
    @staticmethod
    def norm(time_mean, time_deviation):
        return np.random.normal(loc=time_mean, scale=time_deviation)

# %%
class Element:
    id_curr = 0
    
    def __init__(self, name=None, delay_mean=1., delay_dev=0., distribution='', p=None, n_channel=1):
        self.n_channel = n_channel
        self.tnexts = [0.0]*self.n_channel
        self.delay_mean = delay_mean
        self.delay_dev = delay_dev
        self.distribution = distribution
        self.quantity = 0
        self.tcurr = 0
        self.states = [0]*self.n_channel
        self.next_elements = None
        self.p = p
        self.id_curr = Element.id_curr
        Element.id_curr += 1
        self.name = f'element_{self.id_curr}' if name is None else name
        
    def get_delay(self):
        if self.distribution == 'exp':
            return Rand.exp(self.delay_mean)
        elif self.distribution == 'unif':
            return Rand.unif(self.delay_mean, self.delay_dev)
        elif self.distribution == 'norm':
            return Rand.norm(self.delay_mean, self.delay_dev)
        else:
            return self.delay_mean
        
    def in_act(self):
        pass
    
    def out_act(self):
        self.quantity += 1
        
    def print_info(self):
        print(f'{self.name}: state={self.states}; quantity={self.quantity}; tnext={np.round(self.tnexts, 5)}')
        
    def print_result(self):
        print(f'{self.name}: state={self.states}; quantity={self.quantity};\n')
    
    def do_statistics(self, delta):
        pass
    
    def find_free_channels(self):
        res = []
        for i in range(self.n_channel):
            if self.states[i] == 0:
                res.append(i)
        return res
        
    def find_current_channels(self):
        res = []
        for i in range(self.n_channel):
            if self.tnexts[i] == self.tcurr:
                res.append(i)
        return res

# %%
class Create(Element):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
    def out_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        # встановлюємо коли пристрій буде вільним
        self.tnexts[0] = self.tcurr + super().get_delay()
        # передаємо створену заявку на настпуні елемент
        next_element = np.random.choice(self.next_elements, p=self.p)
        next_element.in_act()

# %%
class Despose(Element):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.tnexts = [np.inf]
        
    def in_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        
    def out_act(self):
        pass

# %%
class Process(Element):
    def __init__(self, maxqueue=np.inf, n_channel=1, **kwargs):
        super().__init__(**kwargs)
        self.queue = 0
        self.n_channel = n_channel
        self.maxqueue = maxqueue
        self.mean_queue_length = self.queue
        self.max_obs_queue_length = self.queue
        self.failure = 0
        self.tnexts = [np.inf]*n_channel
        self.states = [0]*n_channel
        
    def in_act(self):
        # перевіряємо чи вільний пристрій
        free_channels = self.find_free_channels()
        for i in free_channels:
            # позначаємо що пристрій зайнятий
            self.states[i] = 1
            # встановлюємо коли пристрій буде вільним
            self.tnexts[i] = self.tcurr + super().get_delay()
            break
        else:
            if self.queue < self.maxqueue:
                self.queue += 1
                if self.queue > self.max_obs_queue_length:
                    self.max_obs_queue_length = self.queue
            else:
                self.failure += 1
            
    def out_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        
        current_channels = self.find_current_channels()
        
        for i in current_channels:
            # позначаємо, що елемент вільний
            self.tnexts[i] = np.inf
            self.states[i] = 0

            # дістаємо з черги елемент, якщо він там є
            if self.queue > 0:
                self.queue -= 1
                self.states[i] = 1
                self.tnexts[i] = self.tcurr + super().get_delay()
            elif self.next_elements is not None:
                next_element = np.random.choice(self.next_elements, p=self.p)
                next_element.in_act()
        
    def print_info(self):
        super().print_info()
        print(f'failure={self.failure}')
        
    def do_statistics(self, delta):
        self.mean_queue_length =+ delta * self.queue

# %%
class Model():
    def __init__(self, elements=[], print_logs=False):
        self.elements = elements
        self.tnext = 0
        self.tcurr = self.tnext
        self.event = elements[0]
        self.print_logs = print_logs
        
    def simulate(self, time):
        self.max_time = time
        while self.tcurr < self.max_time:
            self.tnext = np.inf
            for e in self.elements:
                # знайти найменший з моментів часу
                t_next_min = np.min(e.tnexts)
                if t_next_min < self.tnext and not isinstance(e, Despose):
                    self.tnext = t_next_min
                    self.event = e
            if self.print_logs:
                print(f'\nIt`s time for event in {self.event.name}; time={np.round(self.tnext, 5)}')
            
            # обраховуємо статистики
            for e in self.elements:
                e.do_statistics(self.tnext - self.tcurr)
                
            # робимо переміщення до моменту завершення
            self.tcurr = self.tnext
            for e in self.elements:
                e.tcurr = self.tcurr
            
            # виконуємо операцію завершення
            self.event.out_act()
            
            # Щоб зменшити обсяг обчислень, введемо також здійснення відповідної події для всіх елементів,
            # час наступної події яких співпадає з поточним моментом часу
            for e in self.elements:
                if self.tcurr in e.tnexts:
                    e.out_act()
            if self.print_logs:        
                self.print_info()
        return self.print_result()
        
    def print_info(self):
        for e in self.elements:
            e.print_info()
            
    def print_result(self):
        print('-----RESULT-----')
        
        global_max_observed_queue_length = 0
        global_mean_queue_length_accumulator = 0
        global_failure_probability_accumulator = 0
        global_max_load = 0
        global_mean_load_accumulator = 0
        num_of_processors = 0
        
        for e in self.elements:
            e.print_result()
            if isinstance(e, Process):
                num_of_processors += 1
                mean_queue_length = e.mean_queue_length / self.tcurr
                failure_probability = e.failure / (e.quantity + e.failure) if (e.quantity + e.failure) != 0 else 0
                mean_load = e.quantity / self.max_time
                
                global_mean_queue_length_accumulator += mean_queue_length
                global_failure_probability_accumulator += failure_probability
                global_mean_load_accumulator += mean_load
                
                if e.max_obs_queue_length > global_max_observed_queue_length:
                    global_max_observed_queue_length = e.max_obs_queue_length
                    
                if mean_load > global_max_load:
                    global_max_load = mean_load
                
                if self.print_logs:
                    print(f"Average queue length: {mean_queue_length}")
                    print(f"Failure probability: {failure_probability}")
                    print(f"Average load: {mean_load}")
                    print()
                
        global_mean_queue_length = global_mean_queue_length_accumulator / num_of_processors
        global_failure_probability = global_failure_probability_accumulator / num_of_processors
        global_mean_load = global_mean_load_accumulator / num_of_processors
        
        if self.print_logs:
            print(f"Global max observed queue length: {global_max_observed_queue_length}")
            print(f"Global mean queue length: {global_mean_queue_length}")
            print(f"Global failure probability: {global_failure_probability}")
            print(f"Global max load: {global_max_load}")
            print(f"Global mean load: {global_mean_load}")
            print()
        
        return {
            "global_max_observed_queue_length": global_max_observed_queue_length,
            "global_mean_queue_length": global_mean_queue_length,
            "global_failure_probability": global_failure_probability,
            "global_max_load": global_max_load,
            "global_mean_load": global_mean_load
        }

# %%
class SimModel():
    def __init__(self):
        c1 = Create(delay_mean=1.0, name='CREATOR_1', distribution='exp')
        p1 = Process(maxqueue=2, delay_mean=10.0, name='PROCESSOR1', distribution='exp')

        c1.next_elements = [p1]
        elements = [c1, p1]
        model = Model(elements, print_logs=True)
        model.simulate(10)

# %%
Element.id_curr = 0
s = SimModel()
# Out:
# It`s time for event in CREATOR_1; time=0.0
# CREATOR_1: state=[0]; quantity=1; tnext=[0.99483]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=0
#
# It`s time for event in CREATOR_1; time=0.99483
# CREATOR_1: state=[0]; quantity=2; tnext=[4.70596]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=0
#
# It`s time for event in CREATOR_1; time=4.70596
# CREATOR_1: state=[0]; quantity=3; tnext=[5.73528]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=0
#
# It`s time for event in CREATOR_1; time=5.73528
# CREATOR_1: state=[0]; quantity=4; tnext=[6.24915]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=1
#
# It`s time for event in CREATOR_1; time=6.24915
# CREATOR_1: state=[0]; quantity=5; tnext=[6.95186]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=2
#
# It`s time for event in CREATOR_1; time=6.95186
# CREATOR_1: state=[0]; quantity=6; tnext=[7.19263]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=3
#
# It`s time for event in CREATOR_1; time=7.19263
# CREATOR_1: state=[0]; quantity=7; tnext=[7.57858]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=4
#
# It`s time for event in CREATOR_1; time=7.57858
# CREATOR_1: state=[0]; quantity=8; tnext=[8.03805]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=5
#
# It`s time for event in CREATOR_1; time=8.03805
# CREATOR_1: state=[0]; quantity=9; tnext=[8.03867]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=6
#
# It`s time for event in CREATOR_1; time=8.03867
# CREATOR_1: state=[0]; quantity=10; tnext=[9.07366]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=7
#
# It`s time for event in CREATOR_1; time=9.07366
# CREATOR_1: state=[0]; quantity=11; tnext=[11.39211]
# PROCESSOR1: state=[1]; quantity=0; tnext=[9.47097]
# failure=8
#
# It`s time for event in PROCESSOR1; time=9.47097
# CREATOR_1: state=[0]; quantity=11; tnext=[11.39211]
# PROCESSOR1: state=[1]; quantity=1; tnext=[16.54761]
# failure=8
#
# It`s time for event in CREATOR_1; time=11.39211
# CREATOR_1: state=[0]; quantity=12; tnext=[11.76471]
# PROCESSOR1: state=[1]; quantity=1; tnext=[16.54761]
# failure=8
# -----RESULT-----
# CREATOR_1: state=[0]; quantity=12;
#
# PROCESSOR1: state=[1]; quantity=1;
#
# Average queue length: 0.1686374649156234
# Failure probability: 0.8888888888888888
# Average load: 0.1
#
# Global max observed queue length: 2
# Global mean queue length: 0.1686374649156234
# Global failure probability: 0.8888888888888888
# Global max load: 0.1
# Global mean load: 0.1

# %%
class SimModel2():
    def __init__(self):
        c1 = Create(delay_mean=1, name='CREATOR1', distribution='exp')
        p1 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR1', distribution='exp', n_channel=5)
        p2 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR2', distribution='exp')
        p3 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR3', distribution='exp')
        p4 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR4', distribution='exp')
        d1 = Despose(delay_mean=0, name='DESPOSE1')
        d2 = Despose(delay_mean=0, name='DESPOSE2')
        
        c1.next_elements = [p1]
        p1.next_elements = [p2, p3]
        p2.next_elements = [d1]
        p3.next_elements = [p4]
        p4.next_elements = [p1, d2]
        
        c1.p = [1]
        p1.p = [0.5, 0.5]
        p2.p = [1]
        p3.p = [1]
        p4.p = [0.5, 0.5]
        
        elements = [c1, p1, p2, p3, p4, d1, d2]

        model = Model(elements, print_logs=True)
        model.simulate(50)

# %%
Element.id_curr = 0
s = SimModel2()
# Out:
# It`s time for event in CREATOR1; time=0.0
# CREATOR1: state=[0]; quantity=1; tnext=[0.18476]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=0; tnext=[3.37932     inf     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.18476
# CREATOR1: state=[0]; quantity=2; tnext=[0.91773]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=0; tnext=[3.37932 1.9514      inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.91773
# CREATOR1: state=[0]; quantity=3; tnext=[1.03261]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=0; tnext=[3.37932 1.9514  1.44386     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=1.03261
# CREATOR1: state=[0]; quantity=4; tnext=[3.80245]
# PROCESSOR1: state=[1, 1, 1, 1, 0]; quantity=0; tnext=[3.37932 1.9514  1.44386 2.89722     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=1.44386
# CREATOR1: state=[0]; quantity=4; tnext=[3.80245]
# PROCESSOR1: state=[1, 1, 0, 1, 0]; quantity=1; tnext=[3.37932 1.9514      inf 2.89722     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=1.9514
# CREATOR1: state=[0]; quantity=4; tnext=[3.80245]
# PROCESSOR1: state=[1, 0, 0, 1, 0]; quantity=2; tnext=[3.37932     inf     inf 2.89722     inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=0; tnext=[2.00886]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=2.00886
# CREATOR1: state=[0]; quantity=4; tnext=[3.80245]
# PROCESSOR1: state=[1, 0, 0, 1, 0]; quantity=2; tnext=[3.37932     inf     inf 2.89722     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=1; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=1; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=2.89722
# CREATOR1: state=[0]; quantity=4; tnext=[3.80245]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=3; tnext=[3.37932     inf     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=1; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=1; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=3.37932
# CREATOR1: state=[0]; quantity=4; tnext=[3.80245]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=4; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=1; tnext=[3.67654]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=1; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=3.67654
# CREATOR1: state=[0]; quantity=4; tnext=[3.80245]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=4; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=2; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.80245
# CREATOR1: state=[0]; quantity=5; tnext=[4.61753]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=4; tnext=[4.53863     inf     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=2; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=4.53863
# CREATOR1: state=[0]; quantity=5; tnext=[4.61753]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=5; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=2; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.61753
# CREATOR1: state=[0]; quantity=6; tnext=[6.15972]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=5; tnext=[4.87995     inf     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=2; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=4.87995
# CREATOR1: state=[0]; quantity=6; tnext=[6.15972]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=6; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=2; tnext=[6.23033]
# failure=0
# PROCESSOR3: state=[1]; quantity=0; tnext=[5.64019]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=2; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=5.64019
# CREATOR1: state=[0]; quantity=6; tnext=[6.15972]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=6; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=2; tnext=[6.23033]
# failure=0
# PROCESSOR3: state=[1]; quantity=1; tnext=[6.51568]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=2; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.15972
# CREATOR1: state=[0]; quantity=7; tnext=[6.24931]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=6; tnext=[6.65376     inf     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=2; tnext=[6.23033]
# failure=0
# PROCESSOR3: state=[1]; quantity=1; tnext=[6.51568]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=2; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=6.23033
# CREATOR1: state=[0]; quantity=7; tnext=[6.24931]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=6; tnext=[6.65376     inf     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=1; tnext=[6.51568]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.24931
# CREATOR1: state=[0]; quantity=8; tnext=[6.63795]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=6; tnext=[6.65376 8.60415     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=1; tnext=[6.51568]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=6.51568
# CREATOR1: state=[0]; quantity=8; tnext=[6.63795]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=6; tnext=[6.65376 8.60415     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=2; tnext=[6.54991]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=6.54991
# CREATOR1: state=[0]; quantity=8; tnext=[6.63795]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=6; tnext=[6.65376 8.60415     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=0; tnext=[7.42003]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.63795
# CREATOR1: state=[0]; quantity=9; tnext=[6.84805]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=6; tnext=[6.65376 8.60415 6.87047     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=0; tnext=[7.42003]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=6.65376
# CREATOR1: state=[0]; quantity=9; tnext=[6.84805]
# PROCESSOR1: state=[0, 1, 1, 0, 0]; quantity=7; tnext=[    inf 8.60415 6.87047     inf     inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=3; tnext=[6.67534]
# failure=0
# PROCESSOR3: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=0; tnext=[7.42003]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=6.67534
# CREATOR1: state=[0]; quantity=9; tnext=[6.84805]
# PROCESSOR1: state=[0, 1, 1, 0, 0]; quantity=7; tnext=[    inf 8.60415 6.87047     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=4; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=0; tnext=[7.42003]
# failure=0
# DESPOSE1: state=[0]; quantity=4; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.84805
# CREATOR1: state=[0]; quantity=10; tnext=[6.94825]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=7; tnext=[7.9844  8.60415 6.87047     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=4; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=0; tnext=[7.42003]
# failure=0
# DESPOSE1: state=[0]; quantity=4; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=6.87047
# CREATOR1: state=[0]; quantity=10; tnext=[6.94825]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=8; tnext=[7.9844  8.60415     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=4; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[1]; quantity=0; tnext=[7.42003]
# failure=0
# DESPOSE1: state=[0]; quantity=4; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.94825
# CREATOR1: state=[0]; quantity=11; tnext=[7.95559]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=8; tnext=[7.9844  8.60415 8.80071     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=4; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[1]; quantity=0; tnext=[7.42003]
# failure=0
# DESPOSE1: state=[0]; quantity=4; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR4; time=7.42003
# CREATOR1: state=[0]; quantity=11; tnext=[7.95559]
# PROCESSOR1: state=[1, 1, 1, 1, 0]; quantity=8; tnext=[7.9844  8.60415 8.80071 9.19489     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=4; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=4; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=7.95559
# CREATOR1: state=[0]; quantity=12; tnext=[8.95947]
# PROCESSOR1: state=[1, 1, 1, 1, 1]; quantity=8; tnext=[ 7.9844   8.60415  8.80071  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=4; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=4; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=7.9844
# CREATOR1: state=[0]; quantity=12; tnext=[8.95947]
# PROCESSOR1: state=[0, 1, 1, 1, 1]; quantity=9; tnext=[     inf  8.60415  8.80071  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[1]; quantity=4; tnext=[8.47819]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=4; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=8.47819
# CREATOR1: state=[0]; quantity=12; tnext=[8.95947]
# PROCESSOR1: state=[0, 1, 1, 1, 1]; quantity=9; tnext=[     inf  8.60415  8.80071  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=5; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=5; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=8.60415
# CREATOR1: state=[0]; quantity=12; tnext=[8.95947]
# PROCESSOR1: state=[0, 0, 1, 1, 1]; quantity=10; tnext=[     inf      inf  8.80071  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=5; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=5; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=8.80071
# CREATOR1: state=[0]; quantity=12; tnext=[8.95947]
# PROCESSOR1: state=[0, 0, 0, 1, 1]; quantity=11; tnext=[     inf      inf      inf  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[1]; quantity=5; tnext=[9.1595]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=5; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.95947
# CREATOR1: state=[0]; quantity=13; tnext=[9.02878]
# PROCESSOR1: state=[1, 0, 0, 1, 1]; quantity=11; tnext=[ 9.6228       inf      inf  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[1]; quantity=5; tnext=[9.1595]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=5; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=9.02878
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[1, 1, 0, 1, 1]; quantity=11; tnext=[ 9.6228   9.42746      inf  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[1]; quantity=5; tnext=[9.1595]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=5; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=9.1595
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[1, 1, 0, 1, 1]; quantity=11; tnext=[ 9.6228   9.42746      inf  9.19489 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=6; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=9.19489
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[1, 1, 0, 0, 1]; quantity=12; tnext=[ 9.6228   9.42746      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[1]; quantity=6; tnext=[9.28612]
# failure=0
# PROCESSOR3: state=[1]; quantity=3; tnext=[9.28511]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=6; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=9.28511
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[1, 1, 0, 0, 1]; quantity=12; tnext=[ 9.6228   9.42746      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[1]; quantity=6; tnext=[9.28612]
# failure=0
# PROCESSOR3: state=[1]; quantity=4; tnext=[9.45461]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=6; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=9.28612
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[1, 1, 0, 0, 1]; quantity=12; tnext=[ 9.6228   9.42746      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=4; tnext=[9.45461]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=7; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=9.42746
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[1, 0, 0, 0, 1]; quantity=13; tnext=[ 9.6228       inf      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=4; tnext=[9.45461]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=7; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=9.45461
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[1, 0, 0, 0, 1]; quantity=13; tnext=[ 9.6228       inf      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=5; tnext=[10.13376]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=7; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=9.6228
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[0, 0, 0, 0, 1]; quantity=14; tnext=[     inf      inf      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[1]; quantity=7; tnext=[10.03837]
# failure=0
# PROCESSOR3: state=[1]; quantity=5; tnext=[10.13376]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=7; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=10.03837
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[0, 0, 0, 0, 1]; quantity=14; tnext=[     inf      inf      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=8; tnext=[inf]
# failure=0
# PROCESSOR3: state=[1]; quantity=5; tnext=[10.13376]
# failure=0
# PROCESSOR4: state=[0]; quantity=1; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=8; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=10.13376
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[0, 0, 0, 0, 1]; quantity=14; tnext=[     inf      inf      inf      inf 10.45133]
# failure=0
# PROCESSOR2: state=[0]; quantity=8; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=1; tnext=[11.01327]
# failure=0
# DESPOSE1: state=[0]; quantity=8; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=10.45133
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=15; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=8; tnext=[11.03248]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=1; tnext=[11.01327]
# failure=0
# DESPOSE1: state=[0]; quantity=8; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR4; time=11.01327
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=15; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=8; tnext=[11.03248]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=8; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=11.03248
# CREATOR1: state=[0]; quantity=14; tnext=[13.38134]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=15; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=9; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=13.38134
# CREATOR1: state=[0]; quantity=15; tnext=[14.88916]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=15; tnext=[15.51201      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=9; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=14.88916
# CREATOR1: state=[0]; quantity=16; tnext=[15.17689]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=15; tnext=[15.51201 15.49392      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=9; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=15.17689
# CREATOR1: state=[0]; quantity=17; tnext=[15.79306]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=15; tnext=[15.51201 15.49392 15.68001      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=9; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=15.49392
# CREATOR1: state=[0]; quantity=17; tnext=[15.79306]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=16; tnext=[15.51201      inf 15.68001      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=9; tnext=[16.3131]
# failure=0
# PROCESSOR3: state=[0]; quantity=6; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=15.51201
# CREATOR1: state=[0]; quantity=17; tnext=[15.79306]
# PROCESSOR1: state=[0, 0, 1, 0, 0]; quantity=17; tnext=[     inf      inf 15.68001      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=9; tnext=[16.3131]
# failure=0
# PROCESSOR3: state=[1]; quantity=6; tnext=[16.82339]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=15.68001
# CREATOR1: state=[0]; quantity=17; tnext=[15.79306]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=18; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=9; tnext=[16.3131]
# failure=0
# PROCESSOR3: state=[1]; quantity=6; tnext=[16.82339]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=15.79306
# CREATOR1: state=[0]; quantity=18; tnext=[17.97227]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=18; tnext=[15.93781      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=9; tnext=[16.3131]
# failure=0
# PROCESSOR3: state=[1]; quantity=6; tnext=[16.82339]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=15.93781
# CREATOR1: state=[0]; quantity=18; tnext=[17.97227]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=19; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=9; tnext=[16.3131]
# failure=0
# PROCESSOR3: state=[1]; quantity=6; tnext=[16.82339]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=16.3131
# CREATOR1: state=[0]; quantity=18; tnext=[17.97227]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=19; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=10; tnext=[19.09616]
# failure=0
# PROCESSOR3: state=[1]; quantity=6; tnext=[16.82339]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=16.82339
# CREATOR1: state=[0]; quantity=18; tnext=[17.97227]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=19; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=10; tnext=[19.09616]
# failure=0
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=2; tnext=[18.08208]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=17.97227
# CREATOR1: state=[0]; quantity=19; tnext=[20.12733]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=19; tnext=[18.46851      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=10; tnext=[19.09616]
# failure=0
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=2; tnext=[18.08208]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR4; time=18.08208
# CREATOR1: state=[0]; quantity=19; tnext=[20.12733]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=19; tnext=[18.46851 19.29484      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=10; tnext=[19.09616]
# failure=0
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=18.46851
# CREATOR1: state=[0]; quantity=19; tnext=[20.12733]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=20; tnext=[     inf 19.29484      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=10; tnext=[19.09616]
# failure=0
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=19.09616
# CREATOR1: state=[0]; quantity=19; tnext=[20.12733]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=20; tnext=[     inf 19.29484      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=11; tnext=[21.71415]
# failure=0
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=19.29484
# CREATOR1: state=[0]; quantity=19; tnext=[20.12733]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=21; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=11; tnext=[21.71415]
# failure=0
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=20.12733
# CREATOR1: state=[0]; quantity=20; tnext=[21.21503]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=21; tnext=[21.00969      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=11; tnext=[21.71415]
# failure=0
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=21.00969
# CREATOR1: state=[0]; quantity=20; tnext=[21.21503]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=22; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=11; tnext=[21.71415]
# failure=1
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=21.21503
# CREATOR1: state=[0]; quantity=21; tnext=[22.66694]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=22; tnext=[22.31835      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=11; tnext=[21.71415]
# failure=1
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=21.71415
# CREATOR1: state=[0]; quantity=21; tnext=[22.66694]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=22; tnext=[22.31835      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=12; tnext=[21.94778]
# failure=1
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=21.94778
# CREATOR1: state=[0]; quantity=21; tnext=[22.66694]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=22; tnext=[22.31835      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=13; tnext=[22.17655]
# failure=1
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=9; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=22.17655
# CREATOR1: state=[0]; quantity=21; tnext=[22.66694]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=22; tnext=[22.31835      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=14; tnext=[inf]
# failure=1
# PROCESSOR3: state=[0]; quantity=7; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=10; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=22.31835
# CREATOR1: state=[0]; quantity=21; tnext=[22.66694]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=23; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=14; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=7; tnext=[25.52935]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=10; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=22.66694
# CREATOR1: state=[0]; quantity=22; tnext=[24.68421]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=23; tnext=[22.72532      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=14; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=7; tnext=[25.52935]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=10; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=22.72532
# CREATOR1: state=[0]; quantity=22; tnext=[24.68421]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=24; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=14; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=7; tnext=[25.52935]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=10; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=24.68421
# CREATOR1: state=[0]; quantity=23; tnext=[26.97573]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=24; tnext=[25.98322      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=14; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=7; tnext=[25.52935]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=10; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=25.52935
# CREATOR1: state=[0]; quantity=23; tnext=[26.97573]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=24; tnext=[25.98322      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=14; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=10; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=25.98322
# CREATOR1: state=[0]; quantity=23; tnext=[26.97573]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=25; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=14; tnext=[26.76083]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=10; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=26.76083
# CREATOR1: state=[0]; quantity=23; tnext=[26.97573]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=25; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=15; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=26.97573
# CREATOR1: state=[0]; quantity=24; tnext=[26.97734]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=25; tnext=[28.84437      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=15; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=26.97734
# CREATOR1: state=[0]; quantity=25; tnext=[27.63946]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=25; tnext=[28.84437 27.6731       inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=15; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=27.63946
# CREATOR1: state=[0]; quantity=26; tnext=[28.31264]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=25; tnext=[28.84437 27.6731  28.20726      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=15; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=27.6731
# CREATOR1: state=[0]; quantity=26; tnext=[28.31264]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=26; tnext=[28.84437      inf 28.20726      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=15; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=28.20726
# CREATOR1: state=[0]; quantity=26; tnext=[28.31264]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=27; tnext=[28.84437      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=15; tnext=[28.4241]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=28.31264
# CREATOR1: state=[0]; quantity=27; tnext=[28.38096]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=27; tnext=[28.84437 30.48926      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=15; tnext=[28.4241]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=28.38096
# CREATOR1: state=[0]; quantity=28; tnext=[30.97058]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=27; tnext=[28.84437 30.48926 29.73519      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=15; tnext=[28.4241]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=11; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=28.4241
# CREATOR1: state=[0]; quantity=28; tnext=[30.97058]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=27; tnext=[28.84437 30.48926 29.73519      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=16; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=12; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=28.84437
# CREATOR1: state=[0]; quantity=28; tnext=[30.97058]
# PROCESSOR1: state=[0, 1, 1, 0, 0]; quantity=28; tnext=[     inf 30.48926 29.73519      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=16; tnext=[30.34713]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=12; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=29.73519
# CREATOR1: state=[0]; quantity=28; tnext=[30.97058]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=29; tnext=[     inf 30.48926      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=16; tnext=[30.34713]
# failure=1
# PROCESSOR3: state=[1]; quantity=8; tnext=[29.87335]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=12; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=29.87335
# CREATOR1: state=[0]; quantity=28; tnext=[30.97058]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=29; tnext=[     inf 30.48926      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=16; tnext=[30.34713]
# failure=1
# PROCESSOR3: state=[1]; quantity=9; tnext=[33.07283]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=12; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=30.34713
# CREATOR1: state=[0]; quantity=28; tnext=[30.97058]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=29; tnext=[     inf 30.48926      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=17; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=9; tnext=[33.07283]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=13; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=30.48926
# CREATOR1: state=[0]; quantity=28; tnext=[30.97058]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=30; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=17; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=9; tnext=[33.07283]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=13; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=30.97058
# CREATOR1: state=[0]; quantity=29; tnext=[33.34645]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=30; tnext=[31.83691      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=17; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=9; tnext=[33.07283]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=13; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=31.83691
# CREATOR1: state=[0]; quantity=29; tnext=[33.34645]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=31; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=17; tnext=[32.41412]
# failure=1
# PROCESSOR3: state=[1]; quantity=9; tnext=[33.07283]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=13; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=32.41412
# CREATOR1: state=[0]; quantity=29; tnext=[33.34645]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=31; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=18; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=9; tnext=[33.07283]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=33.07283
# CREATOR1: state=[0]; quantity=29; tnext=[33.34645]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=31; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=18; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=10; tnext=[33.58581]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=33.34645
# CREATOR1: state=[0]; quantity=30; tnext=[33.5943]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=31; tnext=[35.34283      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=18; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=10; tnext=[33.58581]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=33.58581
# CREATOR1: state=[0]; quantity=30; tnext=[33.5943]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=31; tnext=[35.34283      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=18; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=33.5943
# CREATOR1: state=[0]; quantity=31; tnext=[33.92646]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=31; tnext=[35.34283 33.63601      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=18; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=33.63601
# CREATOR1: state=[0]; quantity=31; tnext=[33.92646]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=32; tnext=[35.34283      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=18; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=33.92646
# CREATOR1: state=[0]; quantity=32; tnext=[35.77265]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=32; tnext=[35.34283 34.34916      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=18; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=34.34916
# CREATOR1: state=[0]; quantity=32; tnext=[35.77265]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=33; tnext=[35.34283      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=18; tnext=[35.03047]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=14; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=35.03047
# CREATOR1: state=[0]; quantity=32; tnext=[35.77265]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=33; tnext=[35.34283      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=19; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=15; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=35.34283
# CREATOR1: state=[0]; quantity=32; tnext=[35.77265]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=34; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=19; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=15; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=35.77265
# CREATOR1: state=[0]; quantity=33; tnext=[37.67391]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=34; tnext=[42.94529      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=19; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=11; tnext=[36.89725]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=15; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=36.89725
# CREATOR1: state=[0]; quantity=33; tnext=[37.67391]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=34; tnext=[42.94529      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=19; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=12; tnext=[38.541]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=15; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=37.67391
# CREATOR1: state=[0]; quantity=34; tnext=[37.72185]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=34; tnext=[42.94529 38.93326      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=19; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=12; tnext=[38.541]
# failure=0
# PROCESSOR4: state=[0]; quantity=3; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=15; tnext=[inf]
# ...
#
# It`s time for event in PROCESSOR3; time=42.66151
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=43; tnext=[42.94529      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=23; tnext=[43.3461]
# failure=1
# PROCESSOR3: state=[0]; quantity=17; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=4; tnext=[42.90467]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR4; time=42.90467
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=43; tnext=[42.94529 42.94296 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=23; tnext=[43.3461]
# failure=1
# PROCESSOR3: state=[0]; quantity=17; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=5; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=42.94296
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=44; tnext=[42.94529      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=23; tnext=[43.3461]
# failure=1
# PROCESSOR3: state=[0]; quantity=17; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=5; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=42.94529
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[0, 0, 1, 0, 0]; quantity=45; tnext=[     inf      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=23; tnext=[43.3461]
# failure=1
# PROCESSOR3: state=[1]; quantity=17; tnext=[43.2661]
# failure=0
# PROCESSOR4: state=[0]; quantity=5; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=43.2661
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[0, 0, 1, 0, 0]; quantity=45; tnext=[     inf      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=23; tnext=[43.3461]
# failure=1
# PROCESSOR3: state=[0]; quantity=18; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=5; tnext=[43.91768]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=43.3461
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[0, 0, 1, 0, 0]; quantity=45; tnext=[     inf      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=24; tnext=[44.62217]
# failure=1
# PROCESSOR3: state=[0]; quantity=18; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=5; tnext=[43.91768]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR4; time=43.91768
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=45; tnext=[44.52144      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=24; tnext=[44.62217]
# failure=1
# PROCESSOR3: state=[0]; quantity=18; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=44.52144
# CREATOR1: state=[0]; quantity=42; tnext=[44.6096]
# PROCESSOR1: state=[0, 0, 1, 0, 0]; quantity=46; tnext=[     inf      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=24; tnext=[44.62217]
# failure=1
# PROCESSOR3: state=[1]; quantity=18; tnext=[44.86532]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=44.6096
# CREATOR1: state=[0]; quantity=43; tnext=[44.91286]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=46; tnext=[44.92516      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=24; tnext=[44.62217]
# failure=1
# PROCESSOR3: state=[1]; quantity=18; tnext=[44.86532]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=44.62217
# CREATOR1: state=[0]; quantity=43; tnext=[44.91286]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=46; tnext=[44.92516      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=25; tnext=[44.71504]
# failure=1
# PROCESSOR3: state=[1]; quantity=18; tnext=[44.86532]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=16; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=44.71504
# CREATOR1: state=[0]; quantity=43; tnext=[44.91286]
# PROCESSOR1: state=[1, 0, 1, 0, 0]; quantity=46; tnext=[44.92516      inf 44.74329      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=26; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=18; tnext=[44.86532]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=17; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=44.74329
# CREATOR1: state=[0]; quantity=43; tnext=[44.91286]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=47; tnext=[44.92516      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=26; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=18; tnext=[44.86532]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=17; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=44.86532
# CREATOR1: state=[0]; quantity=43; tnext=[44.91286]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=47; tnext=[44.92516      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=26; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=17; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=44.91286
# CREATOR1: state=[0]; quantity=44; tnext=[46.5182]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=47; tnext=[44.92516 46.29848      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=26; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=17; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=44.92516
# CREATOR1: state=[0]; quantity=44; tnext=[46.5182]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=48; tnext=[     inf 46.29848      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=26; tnext=[45.56379]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=17; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=45.56379
# CREATOR1: state=[0]; quantity=44; tnext=[46.5182]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=48; tnext=[     inf 46.29848      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=27; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=46.29848
# CREATOR1: state=[0]; quantity=44; tnext=[46.5182]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=49; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=27; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=46.5182
# CREATOR1: state=[0]; quantity=45; tnext=[46.62562]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=49; tnext=[46.57417      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=27; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=46.57417
# CREATOR1: state=[0]; quantity=45; tnext=[46.62562]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=50; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=27; tnext=[47.58927]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=46.62562
# CREATOR1: state=[0]; quantity=46; tnext=[49.07264]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=50; tnext=[47.07865      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=27; tnext=[47.58927]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=47.07865
# CREATOR1: state=[0]; quantity=46; tnext=[49.07264]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=51; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=27; tnext=[47.58927]
# failure=1
# PROCESSOR3: state=[1]; quantity=19; tnext=[47.37318]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=47.37318
# CREATOR1: state=[0]; quantity=46; tnext=[49.07264]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=51; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=27; tnext=[47.58927]
# failure=1
# PROCESSOR3: state=[1]; quantity=20; tnext=[47.57544]
# failure=0
# PROCESSOR4: state=[0]; quantity=6; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR3; time=47.57544
# CREATOR1: state=[0]; quantity=46; tnext=[49.07264]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=51; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=27; tnext=[47.58927]
# failure=1
# PROCESSOR3: state=[0]; quantity=21; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=6; tnext=[48.51132]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=47.58927
# CREATOR1: state=[0]; quantity=46; tnext=[49.07264]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=51; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[1]; quantity=28; tnext=[47.62462]
# failure=1
# PROCESSOR3: state=[0]; quantity=21; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=6; tnext=[48.51132]
# failure=0
# DESPOSE1: state=[0]; quantity=18; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR2; time=47.62462
# CREATOR1: state=[0]; quantity=46; tnext=[49.07264]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=51; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[0]; quantity=21; tnext=[inf]
# failure=0
# PROCESSOR4: state=[1]; quantity=6; tnext=[48.51132]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR4; time=48.51132
# CREATOR1: state=[0]; quantity=46; tnext=[49.07264]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=51; tnext=[49.59409      inf      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[0]; quantity=21; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=7; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.07264
# CREATOR1: state=[0]; quantity=47; tnext=[49.2432]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=51; tnext=[49.59409 49.99747      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[0]; quantity=21; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=7; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.2432
# CREATOR1: state=[0]; quantity=48; tnext=[50.5294]
# PROCESSOR1: state=[1, 1, 1, 0, 0]; quantity=51; tnext=[49.59409 49.99747 49.47665      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[0]; quantity=21; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=7; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=49.47665
# CREATOR1: state=[0]; quantity=48; tnext=[50.5294]
# PROCESSOR1: state=[1, 1, 0, 0, 0]; quantity=52; tnext=[49.59409 49.99747      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=21; tnext=[51.37188]
# failure=0
# PROCESSOR4: state=[0]; quantity=7; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=49.59409
# CREATOR1: state=[0]; quantity=48; tnext=[50.5294]
# PROCESSOR1: state=[0, 1, 0, 0, 0]; quantity=53; tnext=[     inf 49.99747      inf      inf      inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=21; tnext=[51.37188]
# failure=0
# PROCESSOR4: state=[0]; quantity=7; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=49.99747
# CREATOR1: state=[0]; quantity=48; tnext=[50.5294]
# PROCESSOR1: state=[0, 0, 0, 0, 0]; quantity=54; tnext=[inf inf inf inf inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=21; tnext=[51.37188]
# failure=0
# PROCESSOR4: state=[0]; quantity=7; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=50.5294
# CREATOR1: state=[0]; quantity=49; tnext=[51.26869]
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=54; tnext=[53.2398     inf     inf     inf     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=29; tnext=[inf]
# failure=1
# PROCESSOR3: state=[1]; quantity=21; tnext=[51.37188]
# failure=0
# PROCESSOR4: state=[0]; quantity=7; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=19; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
# -----RESULT-----
# CREATOR1: state=[0]; quantity=49;
#
# PROCESSOR1: state=[1, 0, 0, 0, 0]; quantity=54;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 1.08
#
# PROCESSOR2: state=[0]; quantity=29;
#
# Average queue length: 0.0
# Failure probability: 0.03333333333333333
# Average load: 0.58
#
# PROCESSOR3: state=[1]; quantity=21;
#
# Average queue length: 0.021054267634555823
# Failure probability: 0.0
# Average load: 0.42
#
# PROCESSOR4: state=[0]; quantity=7;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.14
#
# DESPOSE1: state=[0]; quantity=19;
#
# DESPOSE2: state=[0]; quantity=1;
#
# Global max observed queue length: 2
# Global mean queue length: 0.005263566908638956
# Global failure probability: 0.008333333333333333
# Global max load: 1.08
# Global mean load: 0.555

# %% [markdown]
# **Побудуємо таблицю верифікації:**

# %%
from IPython.display import clear_output

# %%
n_param = 10

delay_create_list = [1]*n_param + [1]*n_param #list(range(1, n_param+1))
delay_process_list = [1]*n_param + [1]*n_param #list(range(1, n_param+1))
maxQ_list = [3]*n_param + [5]*n_param #list(range(1, n_param+1))

time_modeling_list = [i*100 for i in range(1, n_param+1)] + [i*100 for i in range(1, n_param+1)]

# np.random.shuffle(delay_create_list)
# np.random.shuffle(delay_process_list)
# np.random.shuffle(maxQ_list)
# np.random.shuffle(time_modeling_list)

df = pd.DataFrame()
rows = []

for i in range(n_param*2):
    Element.id_curr = 0
    c1 = Create(delay_mean=delay_create_list[i], name='CREATOR_1', distribution='exp')
    p1 = Process(maxqueue=maxQ_list[i], delay_mean=delay_process_list[i], name='PROCESSOR1', distribution='exp')

    c1.next_elements = [p1]
    elements = [c1, p1]
    model = Model(elements, print_logs=False)
    res = model.simulate(time_modeling_list[i])
    
    param = {'delay_mean_create': delay_create_list[i], 'delay_process_create': delay_process_list[i],
             'distribution': 'exp', 'maxqueue': maxQ_list[i], 'time_modeling': time_modeling_list[i]}
    
    rows.append({**param, **res})
df = df.append(rows)
clear_output()

# %% [markdown]
# **Проведемо верифікацію, використовуючи побудовану таблицю:**

# %%
df
# Out:
#     delay_mean_create  delay_process_create distribution  maxqueue  \
# 0                   1                     1          exp         3
# 1                   1                     1          exp         3
# 2                   1                     1          exp         3
# 3                   1                     1          exp         3
# 4                   1                     1          exp         3
# 5                   1                     1          exp         3
# 6                   1                     1          exp         3
# 7                   1                     1          exp         3
# 8                   1                     1          exp         3
# 9                   1                     1          exp         3
# 10                  1                     1          exp         5
# 11                  1                     1          exp         5
# 12                  1                     1          exp         5
# 13                  1                     1          exp         5
# 14                  1                     1          exp         5
# 15                  1                     1          exp         5
# 16                  1                     1          exp         5
# 17                  1                     1          exp         5
# 18                  1                     1          exp         5
# 19                  1                     1          exp         5
#
#     time_modeling  global_max_observed_queue_length  global_mean_queue_length  \
# 0             100                                 3                  0.018254
# 1             200                                 3                  0.000000
# 2             300                                 3                  0.005839
# 3             400                                 3                  0.000000
# 4             500                                 3                  0.001448
# 5             600                                 3                  0.000000
# 6             700                                 3                  0.002052
# 7             800                                 3                  0.000000
# 8             900                                 3                  0.002708
# 9            1000                                 3                  0.000000
# 10            100                                 5                  0.006999
# 11            200                                 5                  0.009229
# 12            300                                 5                  0.000000
# 13            400                                 5                  0.001980
# 14            500                                 5                  0.000000
# 15            600                                 5                  0.004923
# 16            700                                 5                  0.009071
# 17            800                                 5                  0.000390
# 18            900                                 5                  0.004197
# 19           1000                                 5                  0.000340
#
#     global_failure_probability  global_max_load  global_mean_load
# 0                     0.202247         0.710000          0.710000
# 1                     0.222222         0.805000          0.805000
# 2                     0.207237         0.803333          0.803333
# 3                     0.228571         0.742500          0.742500
# 4                     0.198745         0.766000          0.766000
# 5                     0.198697         0.820000          0.820000
# 6                     0.203857         0.825714          0.825714
# 7                     0.205767         0.757500          0.757500
# 8                     0.179912         0.825556          0.825556
# 9                     0.234664         0.786000          0.786000
# 10                    0.076923         0.840000          0.840000
# 11                    0.221675         0.790000          0.790000
# 12                    0.126280         0.853333          0.853333
# 13                    0.155131         0.885000          0.885000
# 14                    0.212844         0.858000          0.858000
# 15                    0.135043         0.843333          0.843333
# 16                    0.117302         0.860000          0.860000
# 17                    0.108586         0.882500          0.882500
# 18                    0.124130         0.838889          0.838889
# 19                    0.115789         0.840000          0.840000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **В данній лабораторній роботі ми реалізували алгоритм імітації простої моделі обслуговування, використовуючи спосіб, який орієнтований на події (аби уникнути випадку, коли дві події приходять в один час).**
# + за допомогою статичних методів була зібрана інформація про роботу/поведінку моделі
# + зміна віхдних параметрів моделі призводить до зміни вихідних значень
# + при досить великій кількості вхідинх параметрів важко проводити етап верифікації моделі
#
# P.S. нижче наведено декілька графіків, які ілюструють залежність вихідних параметрів від вхідних
