# %% [markdown]
# # Lab 3
# + ## Автор: Роман Кривохижа
# + ## Група: ІС-72
# + ## Викладач: Новікова П.А.

# %% [markdown]
# ****
# ****
# ****

# %% [markdown]
# ## Module importing

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
# %matplotlib inline

# %% [markdown]
# ## Algorithm implementation

# %% [markdown]
# + Алгоритм, який відтворює функціонування системи, за допомогою комп’ютерної програми називається **алгоритмом імітації**.
#
# + Вимоги на обслуговування генеруються елементом **CREATE** і відправляються на обслуговування до елементу **PROCESS**, який здійснює обслуговування з часовою затримкою, заданою випадковим числом, та обмеження на довжину черги, заданим невід’ємним числом
#
# + Імітація здійснюється за відомим з попередньої теми принципом: визначається момент найближчої події, просувається час в момент найближчої події та здійснюється відповідна подія.
#
# <font size="4">Ймовірність відмови: $P = \frac{N_{unserv}}{N_{all}}$</font>
#
# <font size="4">Середня довжина черги: $L_{aver} = \frac{\sum_{i} L_i \Delta t_i}{T_{mod}}$</font>
#
# <font size="4">Середній час очікування: $Q_{aver} = \frac{\sum_{i} L_i \Delta t_i}{N_{serv}}$</font>

# %% [markdown]
# <img src="diag.jpg">

# %%
class Rand:
    """
    Генерація випадкового числа за заданим законом розподілу
    """
    @staticmethod
    def exp(time_mean):
        a = 0
        while a == 0:
            a = np.random.rand()
        return -time_mean * np.log(a)
    
    @staticmethod
    def unif(time_min, time_max):
        a = 0
        while a == 0:
            a = np.random.rand()
        a = time_min + a * (time_max - time_min)
        return a
    
    @staticmethod
    def norm(time_mean, time_deviation):
        return np.random.normal(loc=time_mean, scale=time_deviation)

# %%
class Element:
    id_curr = 0
    
    def __init__(self, name=None, delay_mean=1., delay_dev=0., distribution=''):
        self.tnext = 0.0
        self.delay_mean = delay_mean
        self.delay_dev = delay_dev
        self.distribution = distribution
        self.quantity = 0
        self.tcurr = self.tnext
        self.state = 0
        self.next_elements = None
        self.id_curr = Element.id_curr
        Element.id_curr += 1
        self.name = f'element_{self.id_curr}' if name is None else name
        
    def get_delay(self):
        if self.distribution == 'exp':
            return Rand.exp(self.delay_mean)
        elif self.distribution == 'unif':
            return Rand.unif(self.delay_mean, self.delay_dev)
        elif self.distribution == 'norm':
            return Rand.norm(self.delay_mean, self.delay_dev)
        else:
            return self.delay_mean
        
    def in_act(self):
        pass
    
    def out_act(self):
        self.quantity += 1
        
    def print_info(self):
        print(f'{self.name}: state={self.state}; quantity={self.quantity}; tnext={self.tnext}')
        
    def print_result(self):
        print(f'{self.name}: state={self.state}; quantity={self.quantity};\n')
    
    def do_statistics(self, delta):
        pass

# %%
class Create(Element):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
    def out_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        # встановлюємо коли пристрій буде вільним
        self.tnext = self.tcurr + super().get_delay()
        # передаємо створену заявку на настпуні елемент
        # можна задати йммовірність елементу: p = [0.5, 0.2, 0.3]
        next_element = np.random.choice(self.next_elements)
        next_element.in_act()

# %%
class Despose(Element):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.tnext = np.inf
        
    def in_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        
    def out_act(self):
        pass

# %%
class Process(Element):
    def __init__(self, maxqueue=np.inf, **kwargs):
        super().__init__(**kwargs)
        self.queue = 0
        self.maxqueue = maxqueue
        self.mean_queue_length = self.queue
        self.max_obs_queue_length = self.queue
        self.failure = 0
        self.tnext = np.inf
        
    def in_act(self):
        # перевіряємо чи вільний пристрій
        if self.state == 0:
            # позначаємо що пристрій зайнятий
            self.state = 1
            # встановлюємо коли пристрій буде вільним
            self.tnext = self.tcurr + super().get_delay()
        elif self.queue < self.maxqueue:
            self.queue += 1
            if self.queue > self.max_obs_queue_length:
                self.max_obs_queue_length = self.queue
        else:
            self.failure += 1
            
    def out_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        # позначаємо, що елемент вільний
        self.tnext = np.inf
        self.state = 0
        
        # дістаємо з черги елемент, якщо він там є
        if self.queue > 0:
            self.queue -= 1
            self.state = 1
            self.tnext = self.tcurr + super().get_delay()
        elif self.next_elements is not None:
            next_element = np.random.choice(self.next_elements)
            next_element.in_act()
        
    def print_info(self):
        super().print_info()
        print(f'failure={self.failure}')
        
    def do_statistics(self, delta):
        self.mean_queue_length =+ delta * self.queue

# %%
class Model():
    def __init__(self, elements=[], print_logs=False):
        self.elements = elements
        self.tnext = 0
        self.tcurr = self.tnext
        self.event = elements[0]
        self.print_logs = print_logs
        
    def simulate(self, time):
        self.max_time = time
        while self.tcurr < self.max_time:
            self.tnext = np.inf
            for e in self.elements:
                # знайти найменший з моментів часу
                if e.tnext < self.tnext and not isinstance(e, Despose):
                    self.tnext = e.tnext
                    self.event = e
            if self.print_logs:
                print(f'\nIt`s time for event in {self.event.name}; time={self.tnext}')
            
            # обраховуємо статистики
            for e in self.elements:
                e.do_statistics(self.tnext - self.tcurr)
                
            # робимо переміщення до моменту завершення
            self.tcurr = self.tnext
            for e in self.elements:
                e.tcurr = self.tcurr
            
            # виконуємо операцію завершення
            self.event.out_act()
            
            # Щоб зменшити обсяг обчислень, введемо також здійснення відповідної події для всіх елементів,
            # час наступної події яких співпадає з поточним моментом часу
            for e in self.elements:
                if e.tnext == self.tcurr:
                    e.out_act()
            if self.print_logs:        
                self.print_info()
        return self.print_result()
        
    def print_info(self):
        for e in self.elements:
            e.print_info()
            
    def print_result(self):
        print('-----RESULT-----')
        
        global_max_observed_queue_length = 0
        global_mean_queue_length_accumulator = 0
        global_failure_probability_accumulator = 0
        global_max_load = 0
        global_mean_load_accumulator = 0
        num_of_processors = 0
        
        for e in self.elements:
            e.print_result()
            if isinstance(e, Process):
                num_of_processors += 1
                mean_queue_length = e.mean_queue_length / self.tcurr
                failure_probability = e.failure / (e.quantity + e.failure) if (e.quantity + e.failure) != 0 else 0
                mean_load = e.quantity / self.max_time
                
                global_mean_queue_length_accumulator += mean_queue_length
                global_failure_probability_accumulator += failure_probability
                global_mean_load_accumulator += mean_load
                
                if e.max_obs_queue_length > global_max_observed_queue_length:
                    global_max_observed_queue_length = e.max_obs_queue_length
                    
                if mean_load > global_max_load:
                    global_max_load = mean_load
                
                if self.print_logs:
                    print(f"Average queue length: {mean_queue_length}")
                    print(f"Failure probability: {failure_probability}")
                    print(f"Average load: {mean_load}")
                    print()
                
        global_mean_queue_length = global_mean_queue_length_accumulator / num_of_processors
        global_failure_probability = global_failure_probability_accumulator / num_of_processors
        global_mean_load = global_mean_load_accumulator / num_of_processors
        
        if self.print_logs:
            print(f"Global max observed queue length: {global_max_observed_queue_length}")
            print(f"Global mean queue length: {global_mean_queue_length}")
            print(f"Global failure probability: {global_failure_probability}")
            print(f"Global max load: {global_max_load}")
            print(f"Global mean load: {global_mean_load}")
            print()
        
        return {
            "global_max_observed_queue_length": global_max_observed_queue_length,
            "global_mean_queue_length": global_mean_queue_length,
            "global_failure_probability": global_failure_probability,
            "global_max_load": global_max_load,
            "global_mean_load": global_mean_load
        }

# %%
class SimModel():
    def __init__(self):
        c1 = Create(delay_mean=2.0, name='CREATOR_1', distribution='exp')
        p1 = Process(maxqueue=2, delay_mean=4.0, name='PROCESSOR1', distribution='exp')

        c1.next_elements = [p1]
        elements = [c1, p1]
        model = Model(elements, print_logs=True)
        model.simulate(10)

# %%
Element.id_curr = 0
s = SimModel()
# Out:
# It`s time for event in CREATOR_1; time=0.0
# CREATOR_1: state=0; quantity=1; tnext=1.5504001622244867
# PROCESSOR1: state=1; quantity=0; tnext=11.91293202415693
# failure=0
#
# It`s time for event in CREATOR_1; time=1.5504001622244867
# CREATOR_1: state=0; quantity=2; tnext=3.454787513788533
# PROCESSOR1: state=1; quantity=0; tnext=11.91293202415693
# failure=0
#
# It`s time for event in CREATOR_1; time=3.454787513788533
# CREATOR_1: state=0; quantity=3; tnext=4.235287920597912
# PROCESSOR1: state=1; quantity=0; tnext=11.91293202415693
# failure=0
#
# It`s time for event in CREATOR_1; time=4.235287920597912
# CREATOR_1: state=0; quantity=4; tnext=5.0180380787643895
# PROCESSOR1: state=1; quantity=0; tnext=11.91293202415693
# failure=1
#
# It`s time for event in CREATOR_1; time=5.0180380787643895
# CREATOR_1: state=0; quantity=5; tnext=11.816977515958502
# PROCESSOR1: state=1; quantity=0; tnext=11.91293202415693
# failure=2
#
# It`s time for event in CREATOR_1; time=11.816977515958502
# CREATOR_1: state=0; quantity=6; tnext=15.106344423123645
# PROCESSOR1: state=1; quantity=0; tnext=11.91293202415693
# failure=3
# -----RESULT-----
# CREATOR_1: state=0; quantity=6;
#
# PROCESSOR1: state=1; quantity=0;
#
# Average queue length: 1.1507070108261326
# Failure probability: 1.0
# Average load: 0.0
#
# Global max observed queue length: 2
# Global mean queue length: 1.1507070108261326
# Global failure probability: 1.0
# Global max load: 0
# Global mean load: 0.0

# %%
class SimModel2():
    def __init__(self):
        c1 = Create(delay_mean=2.0, name='CREATOR1', distribution='exp')
        p1 = Process(maxqueue=5, delay_mean=1.0, name='PROCESSOR1', distribution='exp')
        p2 = Process(maxqueue=5, delay_mean=1.0, name='PROCESSOR2', distribution='exp')
        p3 = Process(maxqueue=5, delay_mean=1.0, name='PROCESSOR3', distribution='exp')
        p4 = Process(maxqueue=5, delay_mean=1.0, name='PROCESSOR4', distribution='exp')
        d1 = Despose(delay_mean=0, name='DESPOSE1')
#         d2 = Despose(delay_mean=0, name='DESPOSE2')
        
        c1.next_elements = [p1]
        p1.next_elements = [p2, p3]
        p3.next_elements = [p4]
        p4.next_elements = [p1, d1]
        
        elements = [c1, p1, p2, p3, p4, d1]

        model = Model(elements, print_logs=True)
        model.simulate(50)

# %%
Element.id_curr = 0
s = SimModel2()
# Out:
# It`s time for event in CREATOR1; time=0.0
# CREATOR1: state=0; quantity=1; tnext=0.09622657524141724
# PROCESSOR1: state=1; quantity=0; tnext=0.7774363454007043
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in CREATOR1; time=0.09622657524141724
# CREATOR1: state=0; quantity=2; tnext=0.7081927958133996
# PROCESSOR1: state=1; quantity=0; tnext=0.7774363454007043
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in CREATOR1; time=0.7081927958133996
# CREATOR1: state=0; quantity=3; tnext=3.562590654424164
# PROCESSOR1: state=1; quantity=0; tnext=0.7774363454007043
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in PROCESSOR1; time=0.7774363454007043
# CREATOR1: state=0; quantity=3; tnext=3.562590654424164
# PROCESSOR1: state=1; quantity=1; tnext=1.3276038053553254
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in PROCESSOR1; time=1.3276038053553254
# CREATOR1: state=0; quantity=3; tnext=3.562590654424164
# PROCESSOR1: state=1; quantity=2; tnext=3.1928446291475225
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in PROCESSOR1; time=3.1928446291475225
# CREATOR1: state=0; quantity=3; tnext=3.562590654424164
# PROCESSOR1: state=0; quantity=3; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=1; quantity=0; tnext=4.460609684228481
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in CREATOR1; time=3.562590654424164
# CREATOR1: state=0; quantity=4; tnext=3.9670574309396036
# PROCESSOR1: state=1; quantity=3; tnext=4.434661655091778
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=1; quantity=0; tnext=4.460609684228481
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in CREATOR1; time=3.9670574309396036
# CREATOR1: state=0; quantity=5; tnext=7.264171199915094
# PROCESSOR1: state=1; quantity=3; tnext=4.434661655091778
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=1; quantity=0; tnext=4.460609684228481
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in PROCESSOR1; time=4.434661655091778
# CREATOR1: state=0; quantity=5; tnext=7.264171199915094
# PROCESSOR1: state=1; quantity=4; tnext=5.762979841576675
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=1; quantity=0; tnext=4.460609684228481
# failure=0
# PROCESSOR4: state=0; quantity=0; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in PROCESSOR3; time=4.460609684228481
# CREATOR1: state=0; quantity=5; tnext=7.264171199915094
# PROCESSOR1: state=1; quantity=4; tnext=5.762979841576675
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=1; quantity=0; tnext=5.190177008801049
# failure=0
# DESPOSE1: state=0; quantity=0; tnext=inf
#
# It`s time for event in PROCESSOR4; time=5.190177008801049
# CREATOR1: state=0; quantity=5; tnext=7.264171199915094
# PROCESSOR1: state=1; quantity=4; tnext=5.762979841576675
# failure=0
# PROCESSOR2: state=0; quantity=0; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=5.762979841576675
# CREATOR1: state=0; quantity=5; tnext=7.264171199915094
# PROCESSOR1: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR2: state=1; quantity=0; tnext=6.849667164655408
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR2; time=6.849667164655408
# CREATOR1: state=0; quantity=5; tnext=7.264171199915094
# PROCESSOR1: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=7.264171199915094
# CREATOR1: state=0; quantity=6; tnext=15.288410455299193
# PROCESSOR1: state=1; quantity=5; tnext=10.224500721075263
# failure=0
# PROCESSOR2: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=10.224500721075263
# CREATOR1: state=0; quantity=6; tnext=15.288410455299193
# PROCESSOR1: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR2: state=1; quantity=1; tnext=11.725539800171688
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR2; time=11.725539800171688
# CREATOR1: state=0; quantity=6; tnext=15.288410455299193
# PROCESSOR1: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=15.288410455299193
# CREATOR1: state=0; quantity=7; tnext=22.484295708376433
# PROCESSOR1: state=1; quantity=6; tnext=15.958101335513385
# failure=0
# PROCESSOR2: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=15.958101335513385
# CREATOR1: state=0; quantity=7; tnext=22.484295708376433
# PROCESSOR1: state=0; quantity=7; tnext=inf
# failure=0
# PROCESSOR2: state=1; quantity=2; tnext=17.41486795835626
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR2; time=17.41486795835626
# CREATOR1: state=0; quantity=7; tnext=22.484295708376433
# PROCESSOR1: state=0; quantity=7; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=3; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=22.484295708376433
# CREATOR1: state=0; quantity=8; tnext=24.323397551158806
# PROCESSOR1: state=1; quantity=7; tnext=22.499590363559342
# failure=0
# PROCESSOR2: state=0; quantity=3; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=22.499590363559342
# CREATOR1: state=0; quantity=8; tnext=24.323397551158806
# PROCESSOR1: state=0; quantity=8; tnext=inf
# failure=0
# PROCESSOR2: state=1; quantity=3; tnext=22.892291898645258
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR2; time=22.892291898645258
# CREATOR1: state=0; quantity=8; tnext=24.323397551158806
# PROCESSOR1: state=0; quantity=8; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=24.323397551158806
# CREATOR1: state=0; quantity=9; tnext=24.3937520276414
# PROCESSOR1: state=1; quantity=8; tnext=25.78549598142008
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=24.3937520276414
# CREATOR1: state=0; quantity=10; tnext=26.3215090904757
# PROCESSOR1: state=1; quantity=8; tnext=25.78549598142008
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=25.78549598142008
# CREATOR1: state=0; quantity=10; tnext=26.3215090904757
# PROCESSOR1: state=1; quantity=9; tnext=29.56527002434289
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=26.3215090904757
# CREATOR1: state=0; quantity=11; tnext=26.461707906115276
# PROCESSOR1: state=1; quantity=9; tnext=29.56527002434289
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=26.461707906115276
# CREATOR1: state=0; quantity=12; tnext=28.38169515051999
# PROCESSOR1: state=1; quantity=9; tnext=29.56527002434289
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=28.38169515051999
# CREATOR1: state=0; quantity=13; tnext=29.84431546792058
# PROCESSOR1: state=1; quantity=9; tnext=29.56527002434289
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=29.56527002434289
# CREATOR1: state=0; quantity=13; tnext=29.84431546792058
# PROCESSOR1: state=1; quantity=10; tnext=29.656271271722108
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=29.656271271722108
# CREATOR1: state=0; quantity=13; tnext=29.84431546792058
# PROCESSOR1: state=1; quantity=11; tnext=30.231318455973195
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=29.84431546792058
# CREATOR1: state=0; quantity=14; tnext=30.202751749437244
# PROCESSOR1: state=1; quantity=11; tnext=30.231318455973195
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=30.202751749437244
# CREATOR1: state=0; quantity=15; tnext=33.23926175359509
# PROCESSOR1: state=1; quantity=11; tnext=30.231318455973195
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=30.231318455973195
# CREATOR1: state=0; quantity=15; tnext=33.23926175359509
# PROCESSOR1: state=1; quantity=12; tnext=31.222344608061377
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=31.222344608061377
# CREATOR1: state=0; quantity=15; tnext=33.23926175359509
# PROCESSOR1: state=1; quantity=13; tnext=31.608792488002816
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=31.608792488002816
# CREATOR1: state=0; quantity=15; tnext=33.23926175359509
# PROCESSOR1: state=1; quantity=14; tnext=32.230855598211356
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=1; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=32.230855598211356
# CREATOR1: state=0; quantity=15; tnext=33.23926175359509
# PROCESSOR1: state=0; quantity=15; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=1; quantity=1; tnext=33.25248297356522
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=33.23926175359509
# CREATOR1: state=0; quantity=16; tnext=33.33084931789855
# PROCESSOR1: state=1; quantity=15; tnext=34.05188714298472
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=1; quantity=1; tnext=33.25248297356522
# failure=0
# PROCESSOR4: state=0; quantity=1; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR3; time=33.25248297356522
# CREATOR1: state=0; quantity=16; tnext=33.33084931789855
# PROCESSOR1: state=1; quantity=15; tnext=34.05188714298472
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=1; quantity=1; tnext=34.265276488766816
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=33.33084931789855
# CREATOR1: state=0; quantity=17; tnext=33.57764878376247
# PROCESSOR1: state=1; quantity=15; tnext=34.05188714298472
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=1; quantity=1; tnext=34.265276488766816
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in CREATOR1; time=33.57764878376247
# CREATOR1: state=0; quantity=18; tnext=36.52730119375972
# PROCESSOR1: state=1; quantity=15; tnext=34.05188714298472
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=1; quantity=1; tnext=34.265276488766816
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR1; time=34.05188714298472
# CREATOR1: state=0; quantity=18; tnext=36.52730119375972
# PROCESSOR1: state=1; quantity=16; tnext=34.69063464080697
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=1; quantity=1; tnext=34.265276488766816
# failure=0
# DESPOSE1: state=0; quantity=1; tnext=inf
#
# It`s time for event in PROCESSOR4; time=34.265276488766816
# CREATOR1: state=0; quantity=18; tnext=36.52730119375972
# PROCESSOR1: state=1; quantity=16; tnext=34.69063464080697
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=34.69063464080697
# CREATOR1: state=0; quantity=18; tnext=36.52730119375972
# PROCESSOR1: state=1; quantity=17; tnext=35.20254329207405
# failure=0
# PROCESSOR2: state=0; quantity=4; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=35.20254329207405
# CREATOR1: state=0; quantity=18; tnext=36.52730119375972
# PROCESSOR1: state=0; quantity=18; tnext=inf
# failure=0
# PROCESSOR2: state=1; quantity=4; tnext=35.29119106874888
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR2; time=35.29119106874888
# CREATOR1: state=0; quantity=18; tnext=36.52730119375972
# PROCESSOR1: state=0; quantity=18; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=36.52730119375972
# CREATOR1: state=0; quantity=19; tnext=36.64105214703456
# PROCESSOR1: state=1; quantity=18; tnext=36.87459913278001
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=36.64105214703456
# CREATOR1: state=0; quantity=20; tnext=36.96900505877252
# PROCESSOR1: state=1; quantity=18; tnext=36.87459913278001
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=36.87459913278001
# CREATOR1: state=0; quantity=20; tnext=36.96900505877252
# PROCESSOR1: state=1; quantity=19; tnext=37.56454570331891
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=36.96900505877252
# CREATOR1: state=0; quantity=21; tnext=37.363061586333004
# PROCESSOR1: state=1; quantity=19; tnext=37.56454570331891
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=37.363061586333004
# CREATOR1: state=0; quantity=22; tnext=43.02896467826963
# PROCESSOR1: state=1; quantity=19; tnext=37.56454570331891
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=37.56454570331891
# CREATOR1: state=0; quantity=22; tnext=43.02896467826963
# PROCESSOR1: state=1; quantity=20; tnext=37.83496176456341
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=37.83496176456341
# CREATOR1: state=0; quantity=22; tnext=43.02896467826963
# PROCESSOR1: state=1; quantity=21; tnext=38.6708776314142
# failure=0
# PROCESSOR2: state=0; quantity=5; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=38.6708776314142
# CREATOR1: state=0; quantity=22; tnext=43.02896467826963
# PROCESSOR1: state=0; quantity=22; tnext=inf
# failure=0
# PROCESSOR2: state=1; quantity=5; tnext=38.99951287471447
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR2; time=38.99951287471447
# CREATOR1: state=0; quantity=22; tnext=43.02896467826963
# PROCESSOR1: state=0; quantity=22; tnext=inf
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=43.02896467826963
# CREATOR1: state=0; quantity=23; tnext=43.11359058407609
# PROCESSOR1: state=1; quantity=22; tnext=45.35899011860177
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=43.11359058407609
# CREATOR1: state=0; quantity=24; tnext=44.005993352403586
# PROCESSOR1: state=1; quantity=22; tnext=45.35899011860177
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=44.005993352403586
# CREATOR1: state=0; quantity=25; tnext=45.91934404073798
# PROCESSOR1: state=1; quantity=22; tnext=45.35899011860177
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=45.35899011860177
# CREATOR1: state=0; quantity=25; tnext=45.91934404073798
# PROCESSOR1: state=1; quantity=23; tnext=47.58434206368914
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=45.91934404073798
# CREATOR1: state=0; quantity=26; tnext=45.930269658979704
# PROCESSOR1: state=1; quantity=23; tnext=47.58434206368914
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=45.930269658979704
# CREATOR1: state=0; quantity=27; tnext=47.07217151003336
# PROCESSOR1: state=1; quantity=23; tnext=47.58434206368914
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in CREATOR1; time=47.07217151003336
# CREATOR1: state=0; quantity=28; tnext=51.0073793551088
# PROCESSOR1: state=1; quantity=23; tnext=47.58434206368914
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=47.58434206368914
# CREATOR1: state=0; quantity=28; tnext=51.0073793551088
# PROCESSOR1: state=1; quantity=24; tnext=48.187953205699245
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=48.187953205699245
# CREATOR1: state=0; quantity=28; tnext=51.0073793551088
# PROCESSOR1: state=1; quantity=25; tnext=48.471689928270884
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=48.471689928270884
# CREATOR1: state=0; quantity=28; tnext=51.0073793551088
# PROCESSOR1: state=1; quantity=26; tnext=49.30016411921818
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=49.30016411921818
# CREATOR1: state=0; quantity=28; tnext=51.0073793551088
# PROCESSOR1: state=1; quantity=27; tnext=50.38616959602194
# failure=0
# PROCESSOR2: state=0; quantity=6; tnext=inf
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
#
# It`s time for event in PROCESSOR1; time=50.38616959602194
# CREATOR1: state=0; quantity=28; tnext=51.0073793551088
# PROCESSOR1: state=0; quantity=28; tnext=inf
# failure=0
# PROCESSOR2: state=1; quantity=6; tnext=50.65915949150549
# failure=0
# PROCESSOR3: state=0; quantity=2; tnext=inf
# failure=0
# PROCESSOR4: state=0; quantity=2; tnext=inf
# failure=0
# DESPOSE1: state=0; quantity=2; tnext=inf
# -----RESULT-----
# CREATOR1: state=0; quantity=28;
#
# PROCESSOR1: state=0; quantity=28;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.56
#
# PROCESSOR2: state=1; quantity=6;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.12
#
# PROCESSOR3: state=0; quantity=2;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.04
#
# PROCESSOR4: state=0; quantity=2;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.04
#
# DESPOSE1: state=0; quantity=2;
#
# Global max observed queue length: 4
# Global mean queue length: 0.0
# Global failure probability: 0.0
# Global max load: 0.56
# Global mean load: 0.19000000000000003

# %% [markdown]
# **Побудуємо таблицю верифікації:**

# %%
from IPython.display import clear_output

# %%
n_param = 10

delay_create_list = [1]*n_param + [1]*n_param #list(range(1, n_param+1))
delay_process_list = [1]*n_param + [1]*n_param #list(range(1, n_param+1))
maxQ_list = [3]*n_param + [5]*n_param #list(range(1, n_param+1))

time_modeling_list = [i*100 for i in range(1, n_param+1)] + [i*100 for i in range(1, n_param+1)]

# np.random.shuffle(delay_create_list)
# np.random.shuffle(delay_process_list)
# np.random.shuffle(maxQ_list)
# np.random.shuffle(time_modeling_list)

df = pd.DataFrame()
rows = []

for i in range(n_param*2):
    Element.id_curr = 0
    c1 = Create(delay_mean=delay_create_list[i], name='CREATOR_1', distribution='exp')
    p1 = Process(maxqueue=maxQ_list[i], delay_mean=delay_process_list[i], name='PROCESSOR1', distribution='exp')

    c1.next_elements = [p1]
    elements = [c1, p1]
    model = Model(elements, print_logs=False)
    res = model.simulate(time_modeling_list[i])
    
    param = {'delay_mean_create': delay_create_list[i], 'delay_process_create': delay_process_list[i],
             'distribution': 'exp', 'maxqueue': maxQ_list[i], 'time_modeling': time_modeling_list[i]}
    
    rows.append({**param, **res})
df = df.append(rows)
clear_output()

# %% [markdown]
# **Проведемо верифікацію, використовуючи побудовану таблицю:**

# %%
df
# Out:
#     delay_mean_create  delay_process_create distribution  maxqueue  \
# 0                   1                     1          exp         3
# 1                   1                     1          exp         3
# 2                   1                     1          exp         3
# 3                   1                     1          exp         3
# 4                   1                     1          exp         3
# 5                   1                     1          exp         3
# 6                   1                     1          exp         3
# 7                   1                     1          exp         3
# 8                   1                     1          exp         3
# 9                   1                     1          exp         3
# 10                  1                     1          exp         5
# 11                  1                     1          exp         5
# 12                  1                     1          exp         5
# 13                  1                     1          exp         5
# 14                  1                     1          exp         5
# 15                  1                     1          exp         5
# 16                  1                     1          exp         5
# 17                  1                     1          exp         5
# 18                  1                     1          exp         5
# 19                  1                     1          exp         5
#
#     time_modeling  global_max_observed_queue_length  global_mean_queue_length  \
# 0             100                                 3                  0.014104
# 1             200                                 3                  0.012964
# 2             300                                 3                  0.000892
# 3             400                                 3                  0.000000
# 4             500                                 3                  0.007136
# 5             600                                 3                  0.001270
# 6             700                                 3                  0.002674
# 7             800                                 3                  0.002987
# 8             900                                 3                  0.000276
# 9            1000                                 3                  0.001622
# 10            100                                 5                  0.045599
# 11            200                                 5                  0.000000
# 12            300                                 5                  0.000000
# 13            400                                 5                  0.023412
# 14            500                                 5                  0.000000
# 15            600                                 5                  0.000000
# 16            700                                 5                  0.000000
# 17            800                                 5                  0.009583
# 18            900                                 5                  0.004977
# 19           1000                                 5                  0.004055
#
#     global_failure_probability  global_max_load  global_mean_load
# 0                     0.204082         0.780000          0.780000
# 1                     0.169312         0.785000          0.785000
# 2                     0.236422         0.796667          0.796667
# 3                     0.195929         0.790000          0.790000
# 4                     0.197292         0.830000          0.830000
# 5                     0.226073         0.781667          0.781667
# 6                     0.200849         0.807143          0.807143
# 7                     0.179803         0.832500          0.832500
# 8                     0.183673         0.844444          0.844444
# 9                     0.221888         0.775000          0.775000
# 10                    0.058824         0.800000          0.800000
# 11                    0.152284         0.835000          0.835000
# 12                    0.176667         0.823333          0.823333
# 13                    0.137466         0.800000          0.800000
# 14                    0.075055         0.838000          0.838000
# 15                    0.169811         0.806667          0.806667
# 16                    0.122172         0.831429          0.831429
# 17                    0.130660         0.840000          0.840000
# 18                    0.085439         0.844444          0.844444
# 19                    0.154455         0.854000          0.854000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **В данній лабораторній роботі ми реалізували алгоритм імітації простої моделі обслуговування, використовуючи спосіб, який орієнтований на події (аби уникнути випадку, коли дві події приходять в один час).**
# + за допомогою статичних методів була зібрана інформація про роботу/поведінку моделі
# + зміна віхдних параметрів моделі призводить до зміни вихідних значень
# + при досить великій кількості вхідинх параметрів важко проводити етап верифікації моделі
#
# P.S. нижче наведено декілька графіків, які ілюструють залежність вихідних параметрів від вхідних
