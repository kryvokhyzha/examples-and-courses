# %% [markdown]
# # Lab 3
# + ## Автор: Роман Кривохижа
# + ## Група: ІС-72
# + ## Викладач: Новікова П.А.

# %% [markdown]
# ****
# ****
# ****

# %% [markdown]
# ## Module importing

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
# %matplotlib inline

# %% [markdown]
# ## Algorithm implementation

# %% [markdown]
# + Алгоритм, який відтворює функціонування системи, за допомогою комп’ютерної програми називається **алгоритмом імітації**.
#
# + Вимоги на обслуговування генеруються елементом **CREATE** і відправляються на обслуговування до елементу **PROCESS**, який здійснює обслуговування з часовою затримкою, заданою випадковим числом, та обмеження на довжину черги, заданим невід’ємним числом
#
# + Імітація здійснюється за відомим з попередньої теми принципом: визначається момент найближчої події, просувається час в момент найближчої події та здійснюється відповідна подія.
#
# <font size="4">Ймовірність відмови: $P = \frac{N_{unserv}}{N_{all}}$</font>
#
# <font size="4">Середня довжина черги: $L_{aver} = \frac{\sum_{i} L_i \Delta t_i}{T_{mod}}$</font>
#
# <font size="4">Середній час очікування: $Q_{aver} = \frac{\sum_{i} L_i \Delta t_i}{N_{serv}}$</font>

# %% [markdown]
# <img src="diag.jpg">

# %%
class Rand:
    """
    Генерація випадкового числа за заданим законом розподілу
    """
    @staticmethod
    def exp(time_mean):
        a = 0
        while a == 0:
            a = np.random.rand()
        return -time_mean * np.log(a)
    
    @staticmethod
    def unif(time_min, time_max):
        a = 0
        while a == 0:
            a = np.random.rand()
        a = time_min + a * (time_max - time_min)
        return a
    
    @staticmethod
    def norm(time_mean, time_deviation):
        return np.random.normal(loc=time_mean, scale=time_deviation)

# %%
class Element:
    id_curr = 0
    
    def __init__(self, name=None, delay_mean=1., delay_dev=0., distribution='', p=None, n_channel=1):
        self.n_channel = n_channel
        self.tnexts = [0.0]*self.n_channel
        self.delay_mean = delay_mean
        self.delay_dev = delay_dev
        self.distribution = distribution
        self.quantity = 0
        self.tcurr = 0
        self.states = [0]*self.n_channel
        self.next_elements = None
        self.p = p
        self.id_curr = Element.id_curr
        Element.id_curr += 1
        self.name = f'element_{self.id_curr}' if name is None else name
        
    def get_delay(self):
        if self.distribution == 'exp':
            return Rand.exp(self.delay_mean)
        elif self.distribution == 'unif':
            return Rand.unif(self.delay_mean, self.delay_dev)
        elif self.distribution == 'norm':
            return Rand.norm(self.delay_mean, self.delay_dev)
        else:
            return self.delay_mean
        
    def in_act(self):
        pass
    
    def out_act(self):
        self.quantity += 1
        
    def print_info(self):
        print(f'{self.name}: state={self.states}; quantity={self.quantity}; tnext={np.round(self.tnexts, 5)}')
        
    def print_result(self):
        print(f'{self.name}: state={self.states}; quantity={self.quantity};\n')
    
    def do_statistics(self, delta):
        pass
    
    def find_free_channels(self):
        res = []
        for i in range(self.n_channel):
            if self.states[i] == 0:
                res.append(i)
        return res
        
    def find_current_channels(self):
        res = []
        for i in range(self.n_channel):
            if self.tnexts[i] == self.tcurr:
                res.append(i)
        return res

# %%
class Create(Element):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
    def out_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        # встановлюємо коли пристрій буде вільним
        self.tnexts[0] = self.tcurr + super().get_delay()
        # передаємо створену заявку на настпуні елемент
        next_element = np.random.choice(self.next_elements, p=self.p)
        next_element.in_act()

# %%
class Despose(Element):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.tnexts = [np.inf]
        
    def in_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        
    def out_act(self):
        pass

# %%
class Process(Element):
    def __init__(self, maxqueue=np.inf, n_channel=1, **kwargs):
        super().__init__(**kwargs)
        self.queue = 0
        self.n_channel = n_channel
        self.maxqueue = maxqueue
        self.mean_queue_length = self.queue
        self.max_obs_queue_length = self.queue
        self.failure = 0
        self.tnexts = [np.inf]*n_channel
        self.states = [0]*n_channel
        
    def in_act(self):
        # перевіряємо чи вільний пристрій
        free_channels = self.find_free_channels()
        for i in free_channels:
            if i is not None:
                # позначаємо що пристрій зайнятий
                self.states[i] = 1
                # встановлюємо коли пристрій буде вільним
                self.tnexts[i] = self.tcurr + super().get_delay()
                break
        else:
            if self.queue < self.maxqueue:
                self.queue += 1
                if self.queue > self.max_obs_queue_length:
                    self.max_obs_queue_length = self.queue
            else:
                self.failure += 1
            
    def out_act(self):
        # виконуємо збільшення лічильника кількості
        super().out_act()
        
        current_channels = self.find_current_channels()
        
        for i in current_channels:
            # позначаємо, що елемент вільний
            self.tnexts[i] = np.inf
            self.states[i] = 0

            # дістаємо з черги елемент, якщо він там є
            if self.queue > 0:
                self.queue -= 1
                self.states[i] = 1
                self.tnexts[i] = self.tcurr + super().get_delay()
            elif self.next_elements is not None:
                next_element = np.random.choice(self.next_elements, p=self.p)
                next_element.in_act()
        
    def print_info(self):
        super().print_info()
        print(f'failure={self.failure}')
        
    def do_statistics(self, delta):
        self.mean_queue_length =+ delta * self.queue

# %%
class Model():
    def __init__(self, elements=[], print_logs=False):
        self.elements = elements
        self.tnext = 0
        self.tcurr = self.tnext
        self.event = elements[0]
        self.print_logs = print_logs
        
    def simulate(self, time):
        self.max_time = time
        while self.tcurr < self.max_time:
            self.tnext = np.inf
            for e in self.elements:
                # знайти найменший з моментів часу
                t_next_min = np.min(e.tnexts)
                if t_next_min < self.tnext and not isinstance(e, Despose):
                    self.tnext = t_next_min
                    self.event = e
            if self.print_logs:
                print(f'\nIt`s time for event in {self.event.name}; time={np.round(self.tnext, 5)}')
            
            # обраховуємо статистики
            for e in self.elements:
                e.do_statistics(self.tnext - self.tcurr)
                
            # робимо переміщення до моменту завершення
            self.tcurr = self.tnext
            for e in self.elements:
                e.tcurr = self.tcurr
            
            # виконуємо операцію завершення
            self.event.out_act()
            
            # Щоб зменшити обсяг обчислень, введемо також здійснення відповідної події для всіх елементів,
            # час наступної події яких співпадає з поточним моментом часу
            for e in self.elements:
                if self.tcurr in e.tnexts:
                    e.out_act()
            if self.print_logs:        
                self.print_info()
        return self.print_result()
        
    def print_info(self):
        for e in self.elements:
            e.print_info()
            
    def print_result(self):
        print('-----RESULT-----')
        
        global_max_observed_queue_length = 0
        global_mean_queue_length_accumulator = 0
        global_failure_probability_accumulator = 0
        global_max_load = 0
        global_mean_load_accumulator = 0
        num_of_processors = 0
        
        for e in self.elements:
            e.print_result()
            if isinstance(e, Process):
                num_of_processors += 1
                mean_queue_length = e.mean_queue_length / self.tcurr
                failure_probability = e.failure / (e.quantity + e.failure) if (e.quantity + e.failure) != 0 else 0
                mean_load = e.quantity / self.max_time
                
                global_mean_queue_length_accumulator += mean_queue_length
                global_failure_probability_accumulator += failure_probability
                global_mean_load_accumulator += mean_load
                
                if e.max_obs_queue_length > global_max_observed_queue_length:
                    global_max_observed_queue_length = e.max_obs_queue_length
                    
                if mean_load > global_max_load:
                    global_max_load = mean_load
                
                if self.print_logs:
                    print(f"Average queue length: {mean_queue_length}")
                    print(f"Failure probability: {failure_probability}")
                    print(f"Average load: {mean_load}")
                    print()
                
        global_mean_queue_length = global_mean_queue_length_accumulator / num_of_processors
        global_failure_probability = global_failure_probability_accumulator / num_of_processors
        global_mean_load = global_mean_load_accumulator / num_of_processors
        
        if self.print_logs:
            print(f"Global max observed queue length: {global_max_observed_queue_length}")
            print(f"Global mean queue length: {global_mean_queue_length}")
            print(f"Global failure probability: {global_failure_probability}")
            print(f"Global max load: {global_max_load}")
            print(f"Global mean load: {global_mean_load}")
            print()
        
        return {
            "global_max_observed_queue_length": global_max_observed_queue_length,
            "global_mean_queue_length": global_mean_queue_length,
            "global_failure_probability": global_failure_probability,
            "global_max_load": global_max_load,
            "global_mean_load": global_mean_load
        }

# %%
class SimModel():
    def __init__(self):
        c1 = Create(delay_mean=1.0, name='CREATOR_1', distribution='exp')
        p1 = Process(maxqueue=2, delay_mean=10.0, name='PROCESSOR1', distribution='exp')

        c1.next_elements = [p1]
        elements = [c1, p1]
        model = Model(elements, print_logs=True)
        model.simulate(10)

# %%
Element.id_curr = 0
s = SimModel()
# Out:
# It`s time for event in CREATOR_1; time=0.0
# CREATOR_1: state=[0]; quantity=1; tnext=[1.31633]
# PROCESSOR1: state=[1]; quantity=0; tnext=[4.24141]
# failure=0
#
# It`s time for event in CREATOR_1; time=1.31633
# CREATOR_1: state=[0]; quantity=2; tnext=[2.53703]
# PROCESSOR1: state=[1]; quantity=0; tnext=[4.24141]
# failure=0
#
# It`s time for event in CREATOR_1; time=2.53703
# CREATOR_1: state=[0]; quantity=3; tnext=[9.58693]
# PROCESSOR1: state=[1]; quantity=0; tnext=[4.24141]
# failure=0
#
# It`s time for event in PROCESSOR1; time=4.24141
# CREATOR_1: state=[0]; quantity=3; tnext=[9.58693]
# PROCESSOR1: state=[1]; quantity=1; tnext=[22.18639]
# failure=0
#
# It`s time for event in CREATOR_1; time=9.58693
# CREATOR_1: state=[0]; quantity=4; tnext=[9.95626]
# PROCESSOR1: state=[1]; quantity=1; tnext=[22.18639]
# failure=0
#
# It`s time for event in CREATOR_1; time=9.95626
# CREATOR_1: state=[0]; quantity=5; tnext=[10.3934]
# PROCESSOR1: state=[1]; quantity=1; tnext=[22.18639]
# failure=1
#
# It`s time for event in CREATOR_1; time=10.3934
# CREATOR_1: state=[0]; quantity=6; tnext=[10.89808]
# PROCESSOR1: state=[1]; quantity=1; tnext=[22.18639]
# failure=2
# -----RESULT-----
# CREATOR_1: state=[0]; quantity=6;
#
# PROCESSOR1: state=[1]; quantity=1;
#
# Average queue length: 0.08411884864950651
# Failure probability: 0.6666666666666666
# Average load: 0.1
#
# Global max observed queue length: 2
# Global mean queue length: 0.08411884864950651
# Global failure probability: 0.6666666666666666
# Global max load: 0.1
# Global mean load: 0.1

# %%
class SimModel2():
    def __init__(self):
        c1 = Create(delay_mean=0.1, name='CREATOR1', distribution='exp')
        p1 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR1', distribution='exp', n_channel=2)
        p2 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR2', distribution='exp')
        p3 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR3', distribution='exp')
        p4 = Process(maxqueue=2, delay_mean=1.0, name='PROCESSOR4', distribution='exp')
        d1 = Despose(delay_mean=0, name='DESPOSE1')
        d2 = Despose(delay_mean=0, name='DESPOSE2')
        
        c1.next_elements = [p1]
        p1.next_elements = [p2, p3]
        p2.next_elements = [d1]
        p3.next_elements = [p4]
        p4.next_elements = [p1, d2]
        
        c1.p = [1]
        p1.p = [0.5, 0.5]
        p2.p = [1]
        p3.p = [1]
        p4.p = [0.5, 0.5]
        
        elements = [c1, p1, p2, p3, p4, d1, d2]

        model = Model(elements, print_logs=True)
        model.simulate(50)

# %%
Element.id_curr = 0
s = SimModel2()
# Out:
# It`s time for event in CREATOR1; time=0.0
# CREATOR1: state=[0]; quantity=1; tnext=[0.11812]
# PROCESSOR1: state=[1, 0]; quantity=0; tnext=[0.22541     inf]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.11812
# CREATOR1: state=[0]; quantity=2; tnext=[0.142]
# PROCESSOR1: state=[1, 1]; quantity=0; tnext=[0.22541 1.76321]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.142
# CREATOR1: state=[0]; quantity=3; tnext=[0.20857]
# PROCESSOR1: state=[1, 1]; quantity=0; tnext=[0.22541 1.76321]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.20857
# CREATOR1: state=[0]; quantity=4; tnext=[0.24465]
# PROCESSOR1: state=[1, 1]; quantity=0; tnext=[0.22541 1.76321]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=0.22541
# CREATOR1: state=[0]; quantity=4; tnext=[0.24465]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.24465
# CREATOR1: state=[0]; quantity=5; tnext=[0.28409]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=0
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.28409
# CREATOR1: state=[0]; quantity=6; tnext=[0.28845]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=1
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.28845
# CREATOR1: state=[0]; quantity=7; tnext=[0.31408]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=2
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.31408
# CREATOR1: state=[0]; quantity=8; tnext=[0.3333]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=3
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.3333
# CREATOR1: state=[0]; quantity=9; tnext=[0.36198]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=4
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.36198
# CREATOR1: state=[0]; quantity=10; tnext=[0.38306]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=5
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.38306
# CREATOR1: state=[0]; quantity=11; tnext=[0.47935]
# PROCESSOR1: state=[1, 1]; quantity=1; tnext=[0.47426 1.76321]
# failure=6
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=0.47426
# CREATOR1: state=[0]; quantity=11; tnext=[0.47935]
# PROCESSOR1: state=[1, 1]; quantity=2; tnext=[0.83595 1.76321]
# failure=6
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.47935
# CREATOR1: state=[0]; quantity=12; tnext=[0.54105]
# PROCESSOR1: state=[1, 1]; quantity=2; tnext=[0.83595 1.76321]
# failure=6
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.54105
# CREATOR1: state=[0]; quantity=13; tnext=[0.634]
# PROCESSOR1: state=[1, 1]; quantity=2; tnext=[0.83595 1.76321]
# failure=7
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.634
# CREATOR1: state=[0]; quantity=14; tnext=[0.63411]
# PROCESSOR1: state=[1, 1]; quantity=2; tnext=[0.83595 1.76321]
# failure=8
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=0.63411
# CREATOR1: state=[0]; quantity=15; tnext=[1.00513]
# PROCESSOR1: state=[1, 1]; quantity=2; tnext=[0.83595 1.76321]
# failure=9
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=0.83595
# CREATOR1: state=[0]; quantity=15; tnext=[1.00513]
# PROCESSOR1: state=[1, 1]; quantity=3; tnext=[1.06028 1.76321]
# failure=9
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=1.00513
# CREATOR1: state=[0]; quantity=16; tnext=[1.36023]
# PROCESSOR1: state=[1, 1]; quantity=3; tnext=[1.06028 1.76321]
# failure=9
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=1.06028
# CREATOR1: state=[0]; quantity=16; tnext=[1.36023]
# PROCESSOR1: state=[1, 1]; quantity=4; tnext=[1.65171 1.76321]
# failure=9
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=1.36023
# CREATOR1: state=[0]; quantity=17; tnext=[1.43967]
# PROCESSOR1: state=[1, 1]; quantity=4; tnext=[1.65171 1.76321]
# failure=9
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=1.43967
# CREATOR1: state=[0]; quantity=18; tnext=[1.47983]
# PROCESSOR1: state=[1, 1]; quantity=4; tnext=[1.65171 1.76321]
# failure=10
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=1.47983
# CREATOR1: state=[0]; quantity=19; tnext=[1.89695]
# PROCESSOR1: state=[1, 1]; quantity=4; tnext=[1.65171 1.76321]
# failure=11
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=1.65171
# CREATOR1: state=[0]; quantity=19; tnext=[1.89695]
# PROCESSOR1: state=[1, 1]; quantity=5; tnext=[5.73862 1.76321]
# failure=11
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=1.76321
# CREATOR1: state=[0]; quantity=19; tnext=[1.89695]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=11
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=1.89695
# CREATOR1: state=[0]; quantity=20; tnext=[1.98322]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=11
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=1.98322
# CREATOR1: state=[0]; quantity=21; tnext=[2.02879]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=11
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.02879
# CREATOR1: state=[0]; quantity=22; tnext=[2.0774]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=12
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.0774
# CREATOR1: state=[0]; quantity=23; tnext=[2.56249]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=13
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.56249
# CREATOR1: state=[0]; quantity=24; tnext=[2.57383]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=14
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.57383
# CREATOR1: state=[0]; quantity=25; tnext=[2.64762]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=15
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.64762
# CREATOR1: state=[0]; quantity=26; tnext=[2.70108]
# PROCESSOR1: state=[1, 1]; quantity=6; tnext=[5.73862 2.69439]
# failure=16
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=2.69439
# CREATOR1: state=[0]; quantity=26; tnext=[2.70108]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=16
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.70108
# CREATOR1: state=[0]; quantity=27; tnext=[2.83464]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=16
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.83464
# CREATOR1: state=[0]; quantity=28; tnext=[2.91308]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=17
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=2.91308
# CREATOR1: state=[0]; quantity=29; tnext=[3.00619]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=18
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.00619
# CREATOR1: state=[0]; quantity=30; tnext=[3.07542]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=19
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.07542
# CREATOR1: state=[0]; quantity=31; tnext=[3.16565]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=20
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.16565
# CREATOR1: state=[0]; quantity=32; tnext=[3.25271]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=21
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.25271
# CREATOR1: state=[0]; quantity=33; tnext=[3.35985]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=22
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.35985
# CREATOR1: state=[0]; quantity=34; tnext=[3.46444]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=23
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.46444
# CREATOR1: state=[0]; quantity=35; tnext=[3.65725]
# PROCESSOR1: state=[1, 1]; quantity=7; tnext=[5.73862 3.49262]
# failure=24
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=3.49262
# CREATOR1: state=[0]; quantity=35; tnext=[3.65725]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=24
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=3.65725
# CREATOR1: state=[0]; quantity=36; tnext=[4.07812]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=24
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.07812
# CREATOR1: state=[0]; quantity=37; tnext=[4.15383]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=25
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.15383
# CREATOR1: state=[0]; quantity=38; tnext=[4.30529]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=26
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.30529
# CREATOR1: state=[0]; quantity=39; tnext=[4.32165]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=27
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.32165
# CREATOR1: state=[0]; quantity=40; tnext=[4.3497]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=28
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.3497
# CREATOR1: state=[0]; quantity=41; tnext=[4.48048]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=29
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.48048
# CREATOR1: state=[0]; quantity=42; tnext=[4.4832]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=30
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.4832
# CREATOR1: state=[0]; quantity=43; tnext=[4.64336]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=31
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.64336
# CREATOR1: state=[0]; quantity=44; tnext=[4.65802]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=32
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.65802
# CREATOR1: state=[0]; quantity=45; tnext=[4.66765]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=33
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.66765
# CREATOR1: state=[0]; quantity=46; tnext=[4.74953]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=34
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.74953
# CREATOR1: state=[0]; quantity=47; tnext=[4.8347]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=35
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=4.8347
# CREATOR1: state=[0]; quantity=48; tnext=[5.08083]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=36
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=5.08083
# CREATOR1: state=[0]; quantity=49; tnext=[5.21054]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=37
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=5.21054
# CREATOR1: state=[0]; quantity=50; tnext=[5.58595]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=38
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=5.58595
# CREATOR1: state=[0]; quantity=51; tnext=[5.74119]
# PROCESSOR1: state=[1, 1]; quantity=8; tnext=[5.73862 6.51209]
# failure=39
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=5.73862
# CREATOR1: state=[0]; quantity=51; tnext=[5.74119]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=39
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=5.74119
# CREATOR1: state=[0]; quantity=52; tnext=[5.77883]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=39
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=5.77883
# CREATOR1: state=[0]; quantity=53; tnext=[5.79705]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=40
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=5.79705
# CREATOR1: state=[0]; quantity=54; tnext=[5.93769]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=41
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=5.93769
# CREATOR1: state=[0]; quantity=55; tnext=[6.03891]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=42
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.03891
# CREATOR1: state=[0]; quantity=56; tnext=[6.14634]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=43
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.14634
# CREATOR1: state=[0]; quantity=57; tnext=[6.21779]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=44
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.21779
# CREATOR1: state=[0]; quantity=58; tnext=[6.35526]
# PROCESSOR1: state=[1, 1]; quantity=9; tnext=[6.34264 6.51209]
# failure=45
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=6.34264
# CREATOR1: state=[0]; quantity=58; tnext=[6.35526]
# PROCESSOR1: state=[1, 1]; quantity=10; tnext=[6.45351 6.51209]
# failure=45
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.35526
# CREATOR1: state=[0]; quantity=59; tnext=[6.37842]
# PROCESSOR1: state=[1, 1]; quantity=10; tnext=[6.45351 6.51209]
# failure=45
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.37842
# CREATOR1: state=[0]; quantity=60; tnext=[6.45694]
# PROCESSOR1: state=[1, 1]; quantity=10; tnext=[6.45351 6.51209]
# failure=46
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=6.45351
# CREATOR1: state=[0]; quantity=60; tnext=[6.45694]
# PROCESSOR1: state=[1, 1]; quantity=11; tnext=[7.93693 6.51209]
# failure=46
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.45694
# CREATOR1: state=[0]; quantity=61; tnext=[6.4713]
# PROCESSOR1: state=[1, 1]; quantity=11; tnext=[7.93693 6.51209]
# failure=46
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.4713
# CREATOR1: state=[0]; quantity=62; tnext=[6.47342]
# PROCESSOR1: state=[1, 1]; quantity=11; tnext=[7.93693 6.51209]
# failure=47
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.47342
# CREATOR1: state=[0]; quantity=63; tnext=[6.48962]
# PROCESSOR1: state=[1, 1]; quantity=11; tnext=[7.93693 6.51209]
# failure=48
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.48962
# CREATOR1: state=[0]; quantity=64; tnext=[6.66246]
# PROCESSOR1: state=[1, 1]; quantity=11; tnext=[7.93693 6.51209]
# failure=49
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=6.51209
# CREATOR1: state=[0]; quantity=64; tnext=[6.66246]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=49
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.66246
# CREATOR1: state=[0]; quantity=65; tnext=[6.76656]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=49
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.76656
# CREATOR1: state=[0]; quantity=66; tnext=[6.81502]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=50
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.81502
# CREATOR1: state=[0]; quantity=67; tnext=[6.81802]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=51
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.81802
# CREATOR1: state=[0]; quantity=68; tnext=[6.93001]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=52
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.93001
# CREATOR1: state=[0]; quantity=69; tnext=[6.93724]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=53
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.93724
# CREATOR1: state=[0]; quantity=70; tnext=[6.98169]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=54
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=6.98169
# CREATOR1: state=[0]; quantity=71; tnext=[7.15414]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=55
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=7.15414
# CREATOR1: state=[0]; quantity=72; tnext=[7.20687]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=56
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=7.20687
# CREATOR1: state=[0]; quantity=73; tnext=[7.47564]
# PROCESSOR1: state=[1, 1]; quantity=12; tnext=[7.93693 7.24587]
# failure=57
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=7.24587
# CREATOR1: state=[0]; quantity=73; tnext=[7.47564]
# PROCESSOR1: state=[1, 1]; quantity=13; tnext=[7.93693 8.55227]
# failure=57
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=7.47564
# CREATOR1: state=[0]; quantity=74; tnext=[7.48459]
# PROCESSOR1: state=[1, 1]; quantity=13; tnext=[7.93693 8.55227]
# failure=57
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=7.48459
# CREATOR1: state=[0]; quantity=75; tnext=[7.62667]
# PROCESSOR1: state=[1, 1]; quantity=13; tnext=[7.93693 8.55227]
# failure=58
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=7.62667
# CREATOR1: state=[0]; quantity=76; tnext=[7.64378]
# PROCESSOR1: state=[1, 1]; quantity=13; tnext=[7.93693 8.55227]
# failure=59
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=7.64378
# CREATOR1: state=[0]; quantity=77; tnext=[8.03683]
# PROCESSOR1: state=[1, 1]; quantity=13; tnext=[7.93693 8.55227]
# failure=60
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=7.93693
# CREATOR1: state=[0]; quantity=77; tnext=[8.03683]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=60
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.03683
# CREATOR1: state=[0]; quantity=78; tnext=[8.20178]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=60
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.20178
# CREATOR1: state=[0]; quantity=79; tnext=[8.2594]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=61
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.2594
# CREATOR1: state=[0]; quantity=80; tnext=[8.30364]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=62
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.30364
# CREATOR1: state=[0]; quantity=81; tnext=[8.3104]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=63
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.3104
# CREATOR1: state=[0]; quantity=82; tnext=[8.41685]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=64
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.41685
# CREATOR1: state=[0]; quantity=83; tnext=[8.51994]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=65
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.51994
# CREATOR1: state=[0]; quantity=84; tnext=[8.5231]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=66
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.5231
# CREATOR1: state=[0]; quantity=85; tnext=[8.63074]
# PROCESSOR1: state=[1, 1]; quantity=14; tnext=[9.3461  8.55227]
# failure=67
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=8.55227
# CREATOR1: state=[0]; quantity=85; tnext=[8.63074]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=67
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.63074
# CREATOR1: state=[0]; quantity=86; tnext=[8.67294]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=67
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.67294
# CREATOR1: state=[0]; quantity=87; tnext=[8.7678]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=68
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.7678
# CREATOR1: state=[0]; quantity=88; tnext=[8.88751]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=69
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.88751
# CREATOR1: state=[0]; quantity=89; tnext=[8.89184]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=70
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=8.89184
# CREATOR1: state=[0]; quantity=90; tnext=[9.03058]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=71
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=9.03058
# CREATOR1: state=[0]; quantity=91; tnext=[9.14991]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=72
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=9.14991
# CREATOR1: state=[0]; quantity=92; tnext=[9.18387]
# PROCESSOR1: state=[1, 1]; quantity=15; tnext=[9.3461  9.18006]
# failure=73
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=9.18006
# CREATOR1: state=[0]; quantity=92; tnext=[9.18387]
# PROCESSOR1: state=[1, 1]; quantity=16; tnext=[9.3461  9.74414]
# failure=73
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=9.18387
# CREATOR1: state=[0]; quantity=93; tnext=[9.24016]
# PROCESSOR1: state=[1, 1]; quantity=16; tnext=[9.3461  9.74414]
# failure=73
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=9.24016
# CREATOR1: state=[0]; quantity=94; tnext=[9.33489]
# PROCESSOR1: state=[1, 1]; quantity=16; tnext=[9.3461  9.74414]
# failure=74
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in CREATOR1; time=9.33489
# CREATOR1: state=[0]; quantity=95; tnext=[9.42359]
# PROCESSOR1: state=[1, 1]; quantity=16; tnext=[9.3461  9.74414]
# failure=75
# PROCESSOR2: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=0; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=0; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=0; tnext=[inf]
# DESPOSE2: state=[0]; quantity=0; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=9.3461
# CREATOR1: state=[0]; quantity=95; tnext=[9.42359]
# ...
# failure=362
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=47.45361
# CREATOR1: state=[0]; quantity=470; tnext=[47.56954]
# PROCESSOR1: state=[1, 1]; quantity=104; tnext=[47.71295 47.47273]
# failure=363
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=47.47273
# CREATOR1: state=[0]; quantity=470; tnext=[47.56954]
# PROCESSOR1: state=[1, 1]; quantity=105; tnext=[47.71295 48.97441]
# failure=363
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=47.56954
# CREATOR1: state=[0]; quantity=471; tnext=[47.68861]
# PROCESSOR1: state=[1, 1]; quantity=105; tnext=[47.71295 48.97441]
# failure=363
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=47.68861
# CREATOR1: state=[0]; quantity=472; tnext=[47.8157]
# PROCESSOR1: state=[1, 1]; quantity=105; tnext=[47.71295 48.97441]
# failure=364
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=47.71295
# CREATOR1: state=[0]; quantity=472; tnext=[47.8157]
# PROCESSOR1: state=[1, 1]; quantity=106; tnext=[47.89426 48.97441]
# failure=364
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=47.8157
# CREATOR1: state=[0]; quantity=473; tnext=[47.93539]
# PROCESSOR1: state=[1, 1]; quantity=106; tnext=[47.89426 48.97441]
# failure=364
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=47.89426
# CREATOR1: state=[0]; quantity=473; tnext=[47.93539]
# PROCESSOR1: state=[1, 1]; quantity=107; tnext=[48.36335 48.97441]
# failure=364
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=47.93539
# CREATOR1: state=[0]; quantity=474; tnext=[48.06279]
# PROCESSOR1: state=[1, 1]; quantity=107; tnext=[48.36335 48.97441]
# failure=364
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.06279
# CREATOR1: state=[0]; quantity=475; tnext=[48.07452]
# PROCESSOR1: state=[1, 1]; quantity=107; tnext=[48.36335 48.97441]
# failure=365
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.07452
# CREATOR1: state=[0]; quantity=476; tnext=[48.13528]
# PROCESSOR1: state=[1, 1]; quantity=107; tnext=[48.36335 48.97441]
# failure=366
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.13528
# CREATOR1: state=[0]; quantity=477; tnext=[48.23717]
# PROCESSOR1: state=[1, 1]; quantity=107; tnext=[48.36335 48.97441]
# failure=367
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.23717
# CREATOR1: state=[0]; quantity=478; tnext=[48.27097]
# PROCESSOR1: state=[1, 1]; quantity=107; tnext=[48.36335 48.97441]
# failure=368
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.27097
# CREATOR1: state=[0]; quantity=479; tnext=[48.39427]
# PROCESSOR1: state=[1, 1]; quantity=107; tnext=[48.36335 48.97441]
# failure=369
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=48.36335
# CREATOR1: state=[0]; quantity=479; tnext=[48.39427]
# PROCESSOR1: state=[1, 1]; quantity=108; tnext=[49.50532 48.97441]
# failure=369
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.39427
# CREATOR1: state=[0]; quantity=480; tnext=[48.49414]
# PROCESSOR1: state=[1, 1]; quantity=108; tnext=[49.50532 48.97441]
# failure=369
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.49414
# CREATOR1: state=[0]; quantity=481; tnext=[48.5725]
# PROCESSOR1: state=[1, 1]; quantity=108; tnext=[49.50532 48.97441]
# failure=370
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.5725
# CREATOR1: state=[0]; quantity=482; tnext=[48.66376]
# PROCESSOR1: state=[1, 1]; quantity=108; tnext=[49.50532 48.97441]
# failure=371
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.66376
# CREATOR1: state=[0]; quantity=483; tnext=[48.69597]
# PROCESSOR1: state=[1, 1]; quantity=108; tnext=[49.50532 48.97441]
# failure=372
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=48.69597
# CREATOR1: state=[0]; quantity=484; tnext=[49.03799]
# PROCESSOR1: state=[1, 1]; quantity=108; tnext=[49.50532 48.97441]
# failure=373
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=48.97441
# CREATOR1: state=[0]; quantity=484; tnext=[49.03799]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=373
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.03799
# CREATOR1: state=[0]; quantity=485; tnext=[49.04378]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=373
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.04378
# CREATOR1: state=[0]; quantity=486; tnext=[49.06067]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=374
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.06067
# CREATOR1: state=[0]; quantity=487; tnext=[49.07512]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=375
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.07512
# CREATOR1: state=[0]; quantity=488; tnext=[49.12565]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=376
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.12565
# CREATOR1: state=[0]; quantity=489; tnext=[49.14628]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=377
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.14628
# CREATOR1: state=[0]; quantity=490; tnext=[49.20861]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=378
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.20861
# CREATOR1: state=[0]; quantity=491; tnext=[49.31369]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=379
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.31369
# CREATOR1: state=[0]; quantity=492; tnext=[49.61818]
# PROCESSOR1: state=[1, 1]; quantity=109; tnext=[49.50532 49.96418]
# failure=380
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=49.50532
# CREATOR1: state=[0]; quantity=492; tnext=[49.61818]
# PROCESSOR1: state=[1, 1]; quantity=110; tnext=[50.64237 49.96418]
# failure=380
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.61818
# CREATOR1: state=[0]; quantity=493; tnext=[49.68151]
# PROCESSOR1: state=[1, 1]; quantity=110; tnext=[50.64237 49.96418]
# failure=380
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.68151
# CREATOR1: state=[0]; quantity=494; tnext=[49.94874]
# PROCESSOR1: state=[1, 1]; quantity=110; tnext=[50.64237 49.96418]
# failure=381
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=49.94874
# CREATOR1: state=[0]; quantity=495; tnext=[50.06521]
# PROCESSOR1: state=[1, 1]; quantity=110; tnext=[50.64237 49.96418]
# failure=382
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in PROCESSOR1; time=49.96418
# CREATOR1: state=[0]; quantity=495; tnext=[50.06521]
# PROCESSOR1: state=[1, 1]; quantity=111; tnext=[50.64237 50.88903]
# failure=382
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
#
# It`s time for event in CREATOR1; time=50.06521
# CREATOR1: state=[0]; quantity=496; tnext=[50.1922]
# PROCESSOR1: state=[1, 1]; quantity=111; tnext=[50.64237 50.88903]
# failure=382
# PROCESSOR2: state=[0]; quantity=3; tnext=[inf]
# failure=0
# PROCESSOR3: state=[0]; quantity=2; tnext=[inf]
# failure=0
# PROCESSOR4: state=[0]; quantity=2; tnext=[inf]
# failure=0
# DESPOSE1: state=[0]; quantity=3; tnext=[inf]
# DESPOSE2: state=[0]; quantity=1; tnext=[inf]
# -----RESULT-----
# CREATOR1: state=[0]; quantity=496;
#
# PROCESSOR1: state=[1, 1]; quantity=111;
#
# Average queue length: 0.002018016627474259
# Failure probability: 0.7748478701825557
# Average load: 2.22
#
# PROCESSOR2: state=[0]; quantity=3;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.06
#
# PROCESSOR3: state=[0]; quantity=2;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.04
#
# PROCESSOR4: state=[0]; quantity=2;
#
# Average queue length: 0.0
# Failure probability: 0.0
# Average load: 0.04
#
# DESPOSE1: state=[0]; quantity=3;
#
# DESPOSE2: state=[0]; quantity=1;
#
# Global max observed queue length: 2
# Global mean queue length: 0.0005045041568685647
# Global failure probability: 0.19371196754563894
# Global max load: 2.22
# Global mean load: 0.5900000000000001

# %% [markdown]
# **Побудуємо таблицю верифікації:**

# %%
from IPython.display import clear_output

# %%
n_param = 10

delay_create_list = [1]*n_param + [1]*n_param #list(range(1, n_param+1))
delay_process_list = [1]*n_param + [1]*n_param #list(range(1, n_param+1))
maxQ_list = [3]*n_param + [5]*n_param #list(range(1, n_param+1))

time_modeling_list = [i*100 for i in range(1, n_param+1)] + [i*100 for i in range(1, n_param+1)]

# np.random.shuffle(delay_create_list)
# np.random.shuffle(delay_process_list)
# np.random.shuffle(maxQ_list)
# np.random.shuffle(time_modeling_list)

df = pd.DataFrame()
rows = []

for i in range(n_param*2):
    Element.id_curr = 0
    c1 = Create(delay_mean=delay_create_list[i], name='CREATOR_1', distribution='exp')
    p1 = Process(maxqueue=maxQ_list[i], delay_mean=delay_process_list[i], name='PROCESSOR1', distribution='exp')

    c1.next_elements = [p1]
    elements = [c1, p1]
    model = Model(elements, print_logs=False)
    res = model.simulate(time_modeling_list[i])
    
    param = {'delay_mean_create': delay_create_list[i], 'delay_process_create': delay_process_list[i],
             'distribution': 'exp', 'maxqueue': maxQ_list[i], 'time_modeling': time_modeling_list[i]}
    
    rows.append({**param, **res})
df = df.append(rows)
clear_output()

# %% [markdown]
# **Проведемо верифікацію, використовуючи побудовану таблицю:**

# %%
df
# Out:
#     delay_mean_create  delay_process_create distribution  maxqueue  \
# 0                   1                     1          exp         3
# 1                   1                     1          exp         3
# 2                   1                     1          exp         3
# 3                   1                     1          exp         3
# 4                   1                     1          exp         3
# 5                   1                     1          exp         3
# 6                   1                     1          exp         3
# 7                   1                     1          exp         3
# 8                   1                     1          exp         3
# 9                   1                     1          exp         3
# 10                  1                     1          exp         5
# 11                  1                     1          exp         5
# 12                  1                     1          exp         5
# 13                  1                     1          exp         5
# 14                  1                     1          exp         5
# 15                  1                     1          exp         5
# 16                  1                     1          exp         5
# 17                  1                     1          exp         5
# 18                  1                     1          exp         5
# 19                  1                     1          exp         5
#
#     time_modeling  global_max_observed_queue_length  global_mean_queue_length  \
# 0             100                                 3                  0.018254
# 1             200                                 3                  0.000000
# 2             300                                 3                  0.005839
# 3             400                                 3                  0.000000
# 4             500                                 3                  0.001448
# 5             600                                 3                  0.000000
# 6             700                                 3                  0.002052
# 7             800                                 3                  0.000000
# 8             900                                 3                  0.002708
# 9            1000                                 3                  0.000000
# 10            100                                 5                  0.006999
# 11            200                                 5                  0.009229
# 12            300                                 5                  0.000000
# 13            400                                 5                  0.001980
# 14            500                                 5                  0.000000
# 15            600                                 5                  0.004923
# 16            700                                 5                  0.009071
# 17            800                                 5                  0.000390
# 18            900                                 5                  0.004197
# 19           1000                                 5                  0.000340
#
#     global_failure_probability  global_max_load  global_mean_load
# 0                     0.202247         0.710000          0.710000
# 1                     0.222222         0.805000          0.805000
# 2                     0.207237         0.803333          0.803333
# 3                     0.228571         0.742500          0.742500
# 4                     0.198745         0.766000          0.766000
# 5                     0.198697         0.820000          0.820000
# 6                     0.203857         0.825714          0.825714
# 7                     0.205767         0.757500          0.757500
# 8                     0.179912         0.825556          0.825556
# 9                     0.234664         0.786000          0.786000
# 10                    0.076923         0.840000          0.840000
# 11                    0.221675         0.790000          0.790000
# 12                    0.126280         0.853333          0.853333
# 13                    0.155131         0.885000          0.885000
# 14                    0.212844         0.858000          0.858000
# 15                    0.135043         0.843333          0.843333
# 16                    0.117302         0.860000          0.860000
# 17                    0.108586         0.882500          0.882500
# 18                    0.124130         0.838889          0.838889
# 19                    0.115789         0.840000          0.840000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **В данній лабораторній роботі ми реалізували алгоритм імітації простої моделі обслуговування, використовуючи спосіб, який орієнтований на події (аби уникнути випадку, коли дві події приходять в один час).**
# + за допомогою статичних методів була зібрана інформація про роботу/поведінку моделі
# + зміна віхдних параметрів моделі призводить до зміни вихідних значень
# + при досить великій кількості вхідинх параметрів важко проводити етап верифікації моделі
#
# P.S. нижче наведено декілька графіків, які ілюструють залежність вихідних параметрів від вхідних
