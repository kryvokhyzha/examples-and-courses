# %% [markdown]
# ## Problem

# %% [markdown]
# **Task [[kaggle](https://www.kaggle.com/c/reface-fake-detection)]:** recognize fake videos. You need to train the binary classifier to distinguish real videos from fake ones (the provided fake data is the result of the technologies developed in Reface).
#
# ****
#
# ### What I should get?
#
# In order to complete this stage, you should meet one of 2 conditions below:
# + either make a solution with a minimum target metric value of 0.92475
# + or be in the top 30 of all competitors.
#
# ****
#
# ### Evaluation
#
# The evaluation metric for this competition is F1-Score, average='micro'. The F1 score, commonly used in information retrieval, measures accuracy using the statistics precision p and recall r. Precision is the ratio of true positives (tp) to all predicted positives (tp + fp). Recall is the ratio of true positives to all actual positives (tp + fn).
#
# The F1 metric weights recall and precision equally, and a good retrieval algorithm will maximize both precision and recall simultaneously. Thus, moderately good performance on both will be favored over extremely good performance on one and poor performance on the other.
#
# More information you can find at sklearn docs:
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
#
# ****
#
# ### Submission
#
# For each filename in the test set, you must predict either this file is fake video (label 1) or this file is real video (label 0). The file should contain a header and have the following format:
#
# ```
# filename,label
# 004582.mp4,1
# 003603.mp4,0
# ```

# %% [markdown]
# ## Install external modules and load our data

# %%
# !pip install -qq av
# Out:
#      |████████████████████████████████| 37.2 MB 1.1 MB/s

# %%
# !pip install facenet-pytorch > /dev/null 2>&1
# !apt install zip > /dev/null 2>&1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf reface-fake-detection tmp

# %%
# !unzip -qq /content/drive/MyDrive/dl-creator-school/reface-fake-detection/reface-fake-detection.zip -d reface-fake-detection

# %%
# !tar -zcvf train.tar.gz /content/drive/MyDrive/dl-creator-school/reface-fake-detection/train

# %%
# !cp -r /content/drive/MyDrive/dl-creator-school/reface-fake-detection/train train

# %%
# !zip -r train.zip train

# %%
# !ls /content/drive/MyDrive/dl-creator-school/reface-fake-detection/train

# %% [markdown]
# ## Modules importing

# %%
import os
import glob
import json
import cv2

import pandas as pd
import numpy as np

import torch
import torch.nn.functional as F
import torchvision

from torch import nn, optim
from torch.utils.data import sampler
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils import data
from torchvision import transforms, datasets
from torchsummary import summary

from facenet_pytorch import MTCNN

from sklearn.model_selection import train_test_split

from PIL import Image
from tqdm.notebook import tqdm

from typing import List, Dict, Tuple, Union, Optional
from pathlib import Path

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.dpi'] = 150

# %% [markdown]
# ## Settings

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(f'Running on device: {device}')
# Out:
# Running on device: cpu

# %%
PATH2PROJECT = Path('')
PATH2DRIVE = Path('/content/drive/MyDrive/dl-creator-school/')

PATH2DATA = PATH2PROJECT / 'reface-fake-detection'
PATH2TRAIN = PATH2DATA / 'train'
PATH2TEST = PATH2DATA / 'test'
# PATH2SUBMISSIONS = PATH2DRIVE / 'submissions'
# PATH2CHECKOUTS = PATH2DRIVE / 'checkouts'

PATH2RESULT = PATH2PROJECT / 'reface-fake-detection-result'
PATH2RESULT_TRAIN = PATH2RESULT / 'train'
PATH2RESULT_TEST = PATH2RESULT / 'test'

# %%
# try: PATH2SUBMISSIONS.mkdir()
# except: pass
# try: PATH2CHECKOUTS.mkdir()
# except: pass
try: PATH2RESULT.mkdir()
except: pass
try: PATH2RESULT_TRAIN.mkdir()
except: pass
try: PATH2RESULT_TEST.mkdir()
except: pass

# %%
SEED = 42
# VAL_SIZE = 0.3

# %%
SCALE = 0.25
N_FRAMES = 15

# %% [markdown]
# ## Training metadata

# %%
meta_df = pd.read_csv(PATH2DATA / 'train.csv')
meta_df.shape
# Out:
# (41161, 2)

# %%
meta_df.sample(n=5, random_state=SEED)
# Out:
#                                    filename  label
# 12469  dnmwxnsqazhbrzbwhcyeeitekhssbmmx.mp4      1
# 16106  mjfvkdjclgbgbeikregomzvancvoyien.mp4      0
# 144    pbjvfdegxlmysnyelopgwdqglzjgheep.mp4      1
# 6442   rwecopvulhnwevpzsfupgdzwdjfenmcr.mp4      1
# 39989  bvchibtmrvczfpytenatbaqvbulkjbve.mp4      0

# %%
meta_df.label.value_counts(normalize=True)
# Out:
# 0    0.658706
# 1    0.341294
# Name: label, dtype: float64

# %% [markdown]
# ## Stratified split data on test and validation

# %%
# f_train, f_val, y_train, y_val = train_test_split(
#     meta_df[['filename']],
#     meta_df['label'],
#     test_size=VAL_SIZE,
#     random_state=SEED, 
#     stratify=meta_df['label']
# )

# %%
# np.mean(y_train), np.mean(y_val)

# %%
# assert not set(f_train.filename.tolist()) & set(f_val.filename.tolist()), 'intersection is not empty'

# %% [markdown]
# ## Show few frames

# %%
t = os.listdir(PATH2TRAIN / 'train')
temp_filename = t[np.random.randint(0, high=len(t))]
data = torchvision.io.read_video(str(PATH2TRAIN / 'train' / temp_filename), pts_unit='sec')
del t

# %%
vid = data[0]
aud = data[1]

print("Video Shape: {}\nAudio Shape: {}\n".format(vid.shape, aud.shape))
# Out:
# Video Shape: torch.Size([28, 160, 160, 3])
# Audio Shape: torch.Size([1, 17408])

# %%
plt.imshow(vid[10])
plt.title(f"DeepFake Dataset: {temp_filename}; label={meta_df[meta_df.filename == temp_filename].label.values[0]}", loc='left', fontsize=8, pad=5);
plt.axis("off");

# %% [markdown]
# ## Define Face Extractor

# %%
class FaceExtractor:
    def __init__(self, detector, n_frames=None, resize=None):
        """
        Parameters:
            n_frames {int} -- Total number of frames to load. These will be evenly spaced
                throughout the video. If not specified (i.e., None), all frames will be loaded.
                (default: {None})
            resize {float} -- Fraction by which to resize frames from original prior to face
                detection. A value less than 1 results in downsampling and a value greater than
                1 result in upsampling. (default: {None})
        """

        self.detector = detector
        self.n_frames = n_frames
        self.resize = resize
    
    def __call__(self, filename, save_dir):
        """Load frames from an MP4 video, detect faces and save the results.

        Parameters:
            filename {str} -- Path to video.
            save_dir {str} -- The directory where results are saved.
        """

        # Create video reader and find length
        v_cap = cv2.VideoCapture(filename)
        v_len = int(v_cap.get(cv2.CAP_PROP_FRAME_COUNT))

        # Pick 'n_frames' evenly spaced frames to sample
        if self.n_frames is None:
            sample = np.arange(0, v_len)
        else:
            sample = np.linspace(0, v_len - 1, self.n_frames).astype(int)

        # Loop through frames
        for j in range(v_len):
            success = v_cap.grab()
            if j in sample:
                # Load frame
                success, frame = v_cap.retrieve()
                if not success:
                    continue
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frame = Image.fromarray(frame)
                
                # Resize frame to desired size
                if self.resize is not None:
                    frame = frame.resize([int(d * self.resize) for d in frame.size])

                save_path = os.path.join(save_dir, f'{j}.png')

                self.detector([frame], save_path=save_path)

        v_cap.release()

# %% [markdown]
# ## Face extraction process

# %%
# Load face detector
face_detector = MTCNN(margin=14, keep_all=True, factor=0.5, device=device).eval()

# %%
# Define face extractor
face_extractor = FaceExtractor(detector=face_detector, n_frames=N_FRAMES, resize=SCALE)

# %%
# Get the paths of all train videos
all_train_videos = glob.glob(os.path.join(PATH2TRAIN / 'train', '*.mp4'))
all_res_train_videos = os.listdir(PATH2RESULT_TRAIN)

all_train_videos = [path for path in all_train_videos if (path.split('/')[-1].split('.')[0] not in all_res_train_videos)]

# %%
len(glob.glob(os.path.join(PATH2TRAIN / 'train', '*.mp4'))), len(all_train_videos)
# Out:
# (41161, 41161)

# %%
# Get the paths of all test videos
all_test_videos = glob.glob(os.path.join(PATH2TEST / 'test', '*.mp4'))
all_res_test_videos = os.listdir(PATH2RESULT_TEST)

all_test_videos = [path for path in all_test_videos if (path.split('/')[-1].split('.')[0] not in all_res_test_videos)]

# %%
from joblib import Parallel, delayed

# %%
def compute_face_extractor(path, save_path):
    file_name = path.split('/')[-1]

    save_dir = os.path.join(save_path, file_name.split(".")[0])

    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Detect all faces appear in the video and save them.
    face_extractor(path, save_dir)

# %%
with torch.no_grad():
    Parallel(n_jobs=-1, verbose=5)(delayed(compute_face_extractor)(path, PATH2RESULT_TRAIN) for path in tqdm(all_train_videos))
# Out:
#   0%|          | 0/41161 [00:00<?, ?it/s]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 878 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 1148 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 1454 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 1796 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 2174 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 2588 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 3038 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 3524 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=-1)]: Done 4046 tasks      | elapsed: 27.6min
# [Parallel(n_jobs=-1)]: Done 4604 tasks      | elapsed: 31.4min
# [Parallel(n_jobs=-1)]: Done 5198 tasks      | elapsed: 35.4min
# [Parallel(n_jobs=-1)]: Done 5828 tasks      | elapsed: 39.6min
# [Parallel(n_jobs=-1)]: Done 6494 tasks      | elapsed: 44.2min
# [Parallel(n_jobs=-1)]: Done 7196 tasks      | elapsed: 49.0min
# [Parallel(n_jobs=-1)]: Done 7934 tasks      | elapsed: 54.0min
# [Parallel(n_jobs=-1)]: Done 8708 tasks      | elapsed: 59.4min
# [Parallel(n_jobs=-1)]: Done 9518 tasks      | elapsed: 64.9min
# [Parallel(n_jobs=-1)]: Done 10364 tasks      | elapsed: 70.7min
# [Parallel(n_jobs=-1)]: Done 11246 tasks      | elapsed: 76.8min
# [Parallel(n_jobs=-1)]: Done 12164 tasks      | elapsed: 83.2min
# [Parallel(n_jobs=-1)]: Done 13118 tasks      | elapsed: 89.8min
# [Parallel(n_jobs=-1)]: Done 14108 tasks      | elapsed: 96.7min
# [Parallel(n_jobs=-1)]: Done 15134 tasks      | elapsed: 103.8min
# [Parallel(n_jobs=-1)]: Done 16196 tasks      | elapsed: 111.2min
# [Parallel(n_jobs=-1)]: Done 17294 tasks      | elapsed: 118.8min
# [Parallel(n_jobs=-1)]: Done 18428 tasks      | elapsed: 126.6min
# [Parallel(n_jobs=-1)]: Done 19598 tasks      | elapsed: 134.6min
# [Parallel(n_jobs=-1)]: Done 20804 tasks      | elapsed: 142.9min
# [Parallel(n_jobs=-1)]: Done 22046 tasks      | elapsed: 151.5min
# [Parallel(n_jobs=-1)]: Done 23324 tasks      | elapsed: 160.2min
# [Parallel(n_jobs=-1)]: Done 24638 tasks      | elapsed: 169.4min
# [Parallel(n_jobs=-1)]: Done 25988 tasks      | elapsed: 178.8min
# [Parallel(n_jobs=-1)]: Done 27374 tasks      | elapsed: 188.3min
# [Parallel(n_jobs=-1)]: Done 28796 tasks      | elapsed: 198.2min
# [Parallel(n_jobs=-1)]: Done 30254 tasks      | elapsed: 208.2min
# [Parallel(n_jobs=-1)]: Done 31748 tasks      | elapsed: 218.6min
# [Parallel(n_jobs=-1)]: Done 33278 tasks      | elapsed: 229.1min
# [Parallel(n_jobs=-1)]: Done 34844 tasks      | elapsed: 239.9min
# [Parallel(n_jobs=-1)]: Done 36446 tasks      | elapsed: 250.6min
# [Parallel(n_jobs=-1)]: Done 38084 tasks      | elapsed: 261.9min
# [Parallel(n_jobs=-1)]: Done 39758 tasks      | elapsed: 273.4min
# [Parallel(n_jobs=-1)]: Done 41161 out of 41161 | elapsed: 282.9min finished

# %%
# Parallel(n_jobs=-1, verbose=5)(delayed(compute_face_extractor)(path, PATH2RESULT_TEST) for path in tqdm(all_test_videos))

# %%
meta_df.to_csv(PATH2RESULT / 'train.csv', index=False)

# %%
# !tar -zcvf reface-fake-detection-result.tar.gz reface-fake-detection-result
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# reface-fake-detection-result/train/xjnlqlgrasfwahsycgjenwaaffjvveax/15.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/22.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/45.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/59.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/41.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/18.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/54.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/4.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/50.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/36.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/0.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/9.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/27.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/32.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/13.png
# reface-fake-detection-result/train/rqdilfzcsvnjwanufqlcqdgwlbalgdex/64.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/6.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/8.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/14.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/21.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/18.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/4.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/3.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/11.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/0.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/9.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/16.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/19.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/1.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/23.png
# reface-fake-detection-result/train/kbvexicsplpttxkfqqdnmytdcmtbfghb/13.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/6.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/22.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/12.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/8.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/24.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/20.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/14.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/18.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/4.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/0.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/2.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/26.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/16.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/10.png
# reface-fake-detection-result/train/psfptdnlecqwelkdgwwsklytorskccyt/29.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/76.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/59.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/38.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/5.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/21.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/54.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/70.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/65.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/0.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/27.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/48.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/43.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/16.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/10.png
# reface-fake-detection-result/train/kbqullougbkvokyrzseacglwmszdmyvt/32.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/22.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/45.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/60.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/90.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/7.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/106.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/53.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/75.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/0.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/30.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/98.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/83.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/37.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/68.png
# reface-fake-detection-result/train/kklrzjlilsegarixjdwrmipqcxmotzgz/15.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/40.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/20.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/130.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/60.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/90.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/120.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/80.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/50.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/141.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/70.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/0.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/30.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/110.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/100.png
# reface-fake-detection-result/train/cmbwevebadwbotwfdghipfzmsxmwuyve/10.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/59.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/79.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/139.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/159.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/219.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/0.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/199.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/179.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/99.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/279.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/19.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/39.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/259.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/239.png
# reface-fake-detection-result/train/elmptwiassqloypscuswsgjmfpzctoyk/119.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/12.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/8.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/24.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/40.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/20.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/44.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/4.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/36.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/28.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/0.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/48.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/52.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/16.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/32.png
# reface-fake-detection-result/train/gbpqwiukjwxylsmmrinysudpwlllemhj/57.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/6.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/12.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/24.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/21.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/18.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/3.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/42.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/33.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/36.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/0.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/30.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/9.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/27.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/39.png
# reface-fake-detection-result/train/aubkbpcrbtbkkpymvafawwmrmgmnfdtz/15.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/78.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/107.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/88.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/58.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/0.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/127.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/117.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/137.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/97.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/9.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/48.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/19.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/39.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/68.png
# reface-fake-detection-result/train/yfpmcjwocuiewhikhaceyuhdtgwvmowq/29.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/8.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/20.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/14.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/38.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/5.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/41.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/35.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/11.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/17.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/0.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/2.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/26.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu/32.png
# reface-fake-detection-result/train/ebncdtcgftxdzddjinfflxiwiiuskyvu
png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/6.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/22.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/12.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/40.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/34.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/18.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/44.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/3.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/28.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/0.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/9.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/31.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/37.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/25.png
# reface-fake-detection-result/train/kvvqaqycjfrwzakeourmboxdzxkdlzvz/15.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/6.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/12.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/24.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/21.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/18.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/3.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/33.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/36.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/0.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/30.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/9.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/27.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/43.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/39.png
# reface-fake-detection-result/train/kepmqpajvlbzeeyealbjeqvyepvameig/15.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/38.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/126.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/58.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/106.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/116.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/0.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/97.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/9.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/48.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/77.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/136.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/19.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/68.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/87.png
# reface-fake-detection-result/train/wggrshelipbveinuaibqedumisimybzj/29.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/24.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/221.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/295.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/197.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/320.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/123.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/0.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/73.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/345.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/98.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/246.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/49.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/147.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/172.png
# reface-fake-detection-result/train/rwmwtchimlklmxysaknvukzryjdgqojj/271.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/6.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/12.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/21.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/7.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/18.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/4.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/3.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/0.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/9.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/16.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/19.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/10.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/1.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/13.png
# reface-fake-detection-result/train/flzpaxrfishujmoinzsnenelpmeeydxv/15.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/8.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/56.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/47.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/34.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/21.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/4.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/17.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/0.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/30.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/61.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/26.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/43.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/52.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/39.png
# reface-fake-detection-result/train/oibqingvsjcnlozlamhrwzkllkgmvscq/13.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/12.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/8.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/24.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/56.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/40.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/20.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/44.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/4.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/36.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/28.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/0.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/48.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/52.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/16.png
# reface-fake-detection-result/train/kcmxiklrwebraclguyqbzuxfdekfqbxq/32.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/22.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/24.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/20.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/14.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/5.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/7.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/18.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/3.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/11.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/0.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/26.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/9.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/16.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/1.png
# reface-fake-detection-result/train/xammyoxuwmjasmnhtlqxkmzsmvedxjzt/13.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/71.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/59.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/5.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/41.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/47.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/35.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/11.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/17.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/53.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/65.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/0.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/77.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/83.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/23.png
# reface-fake-detection-result/train/dccfptzbyplxdkjqjsnrgsyermvryljs/29.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/22.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/24.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/20.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/14.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/5.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/7.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/18.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/3.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/11.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/0.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/26.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/9.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/16.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/1.png
# reface-fake-detection-result/train/xopuvcfzkguvxvdxjbtitjvtspiwreif/13.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/8.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/66.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/41.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/58.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/50.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/33.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/75.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/0.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/117.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/91.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/16.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/100.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/83.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/25.png
# reface-fake-detection-result/train/hxqhvpgimyknahvbyjtvzdlkcmjgxrsl/108.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/78.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/107.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/88.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/58.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/0.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/127.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/117.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/137.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/97.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/9.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/48.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/19.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/39.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/68.png
# reface-fake-detection-result/train/vynodjfotehxzvoncsnizyetrwsooudv/29.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/6.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/22.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/12.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/8.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/24.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/20.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/14.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/18.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/4.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/0.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/2.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/26.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/16.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/10.png
# reface-fake-detection-result/train/ubonprsibijpwyzflopskeyqdeqrprxg/29.png
# reface-fake-detection-result/train.csv
# reface-fake-detection-result/test/

# %%
# !cp reface-fake-detection-result.tar.gz /content/drive/MyDrive/dl-creator-school/reface-fake-detection-result.tar.gz

# %%
# !ls /content/drive/MyDrive/dl-creator-school
# Out:
# reface-fake-detection-result.tar.gz

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Colab Notebooks'   dl-creator-school

# %%
from google.colab import files
files.download('reface-fake-detection-result.tar.gz')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !rm -rf $PATH2TRAIN/'train'

# %%
# !rm -rf $PATH2TEST/'test'
