# %% [markdown]
# ## Problem

# %% [markdown]
# **Task [[kaggle](https://www.kaggle.com/c/reface-fake-detection)]:** recognize fake videos. You need to train the binary classifier to distinguish real videos from fake ones (the provided fake data is the result of the technologies developed in Reface).
#
# ****
#
# ### What I should get?
#
# In order to complete this stage, you should meet one of 2 conditions below:
# + either make a solution with a minimum target metric value of 0.92475
# + or be in the top 30 of all competitors.
#
# ****
#
# ### Evaluation
#
# The evaluation metric for this competition is F1-Score, average='micro'. The F1 score, commonly used in information retrieval, measures accuracy using the statistics precision p and recall r. Precision is the ratio of true positives (tp) to all predicted positives (tp + fp). Recall is the ratio of true positives to all actual positives (tp + fn).
#
# The F1 metric weights recall and precision equally, and a good retrieval algorithm will maximize both precision and recall simultaneously. Thus, moderately good performance on both will be favored over extremely good performance on one and poor performance on the other.
#
# More information you can find at sklearn docs:
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
#
# ****
#
# ### Submission
#
# For each filename in the test set, you must predict either this file is fake video (label 1) or this file is real video (label 0). The file should contain a header and have the following format:
#
# ```
# filename,label
# 004582.mp4,1
# 003603.mp4,0
# ```

# %% [markdown]
# ## Install external modules and load our data

# %%
# !pip install -qq kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d kryvokhyzha/refacefakedetectionimages8
# !kaggle datasets download -d kryvokhyzha/refacefakedetectionimages8
# Out:
# Downloading refacefakedetectionimages8.zip to /content
# 100% 12.1G/12.1G [03:26<00:00, 126MB/s]
# 100% 12.1G/12.1G [03:26<00:00, 62.9MB/s]

# %%
# !unzip refacefakedetectionimages8.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: reface-fake-detection-result/train/zpssxxottsrxdniwwfqxyskraufhvgje/30.png
#   inflating: reface-fake-detection-result/train/zpssxxottsrxdniwwfqxyskraufhvgje/40.png
#   inflating: reface-fake-detection-result/train/zpssxxottsrxdniwwfqxyskraufhvgje/60.png
#   inflating: reface-fake-detection-result/train/zpssxxottsrxdniwwfqxyskraufhvgje/71.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/0.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/16.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/24.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/32.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/40.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/48.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/56.png
#   inflating: reface-fake-detection-result/train/zpsumhnxlcdvstibcaemiyqrwumnnaxl/8.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/0.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/14.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/22.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/29.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/37.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/44.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/52.png
#   inflating: reface-fake-detection-result/train/zpsyhenqedntiqjohaxeqhikvdftthvw/7.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/0.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/11.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/17.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/22.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/28.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/34.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/40.png
#   inflating: reface-fake-detection-result/train/zptxbopgdxxxyqieekivhdjozoqcycgz/5.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/0.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/100.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/120.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/141.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/20.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/40.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/60.png
#   inflating: reface-fake-detection-result/train/zpudoacskepzryeglcutuqklelijwflh/80.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/0.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/14.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/21.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/28.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/35.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/42.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/49.png
#   inflating: reface-fake-detection-result/train/zpuncvdlhszhybonlrxeszfjncfnzjkq/7.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/0.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/100.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/134.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/167.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/201.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/235.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/33.png
#   inflating: reface-fake-detection-result/train/zpuwfiqpzxvipxpflktfzzeiwsmlwphp/67.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/0.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/12.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/25.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/37.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/50.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/62.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/75.png
#   inflating: reface-fake-detection-result/train/zpvolfznuacluutroyjbfutxrtbsyavm/88.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/0.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/114.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/137.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/160.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/22.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/45.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/68.png
#   inflating: reface-fake-detection-result/train/zpxsbyusnadkfkkkvwydqrthjzvigiph/91.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/0.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/12.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/17.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/21.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/25.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/30.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/4.png
#   inflating: reface-fake-detection-result/train/zpxsswpilmzychpqlkijeadynccyqjjq/8.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/0.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/19.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/29.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/39.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/49.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/59.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/69.png
#   inflating: reface-fake-detection-result/train/zpydukqoyapfxggikbonwskkemdwocpl/9.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/0.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/15.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/22.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/30.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/37.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/45.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/53.png
#   inflating: reface-fake-detection-result/train/zpyjynrulvgjddvgjrmcxhvedbifipwb/7.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/0.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/13.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/17.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/22.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/26.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/31.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/4.png
#   inflating: reface-fake-detection-result/train/zpyoyjesbambzxpkynobblvdqqbcbwhm/8.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/0.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/10.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/14.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/17.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/21.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/25.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/3.png
#   inflating: reface-fake-detection-result/train/zpypdtppxwhzdflhacjfizrgfwleopit/7.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/0.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/13.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/19.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/26.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/32.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/39.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/46.png
#   inflating: reface-fake-detection-result/train/zpzrsjwsnbkbgbsswbjkadcakthpqbcj/6.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/0.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/10.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/14.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/17.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/21.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/25.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/3.png
#   inflating: reface-fake-detection-result/train/zpzssmqyoekqgoyyuntilptugtnqrekg/7.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/0.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/13.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/20.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/26.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/33.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/40.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/47.png
#   inflating: reface-fake-detection-result/train/zqalhcjkalbmxzowzwvxyoxhqofhszcj/6.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/0.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/120.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/150.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/180.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/210.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/30.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/60.png
#   inflating: reface-fake-detection-result/train/zqamztkmtbxcheqajnztyzkwarnfmjql/90.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/0.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/13.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/27.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/41.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/54.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/68.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/82.png
#   inflating: reface-fake-detection-result/train/zqbxyxbfawfdzkhpfftblzwkkwtaqlpn/96.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/0.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/11.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/17.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/23.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/29.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/35.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/41.png
#   inflating: reface-fake-detection-result/train/zqcvnmhmtfqgsdwyspqwoxorsbngfqcp/5.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/0.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/12.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/15.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/18.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/21.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/3.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/6.png
#   inflating: reface-fake-detection-result/train/zqdcqywlnracronxviqiidxfujrdxmhs/9.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/0.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/19.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/28.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/38.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/47.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/57.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/67.png
#   inflating: reface-fake-detection-result/train/zqdnrxpajatazlcmxshmppzxaafvzggv/9.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/0.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/14.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/18.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/23.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/28.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/33.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/4.png
#   inflating: reface-fake-detection-result/train/zqdxcysgwxluvrfkluibgygyxybdunnu/9.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/0.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/138.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/208.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/277.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/347.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/416.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/486.png
#   inflating: reface-fake-detection-result/train/zqefntlufbbfpaqhkbiibxjoucomnvci/69.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/0.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/18.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/27.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/36.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/45.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/54.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/63.png
#   inflating: reface-fake-detection-result/train/zqevyggaohunwxuvawwzqwxvsjleyuej/9.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/0.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/10.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/21.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/32.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/43.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/54.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/65.png
#   inflating: reface-fake-detection-result/train/zqfewzqvpxfntrtlhykounczavklzuzi/76.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/0.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/108.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/15.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/30.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/46.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/61.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/77.png
#   inflating: reface-fake-detection-result/train/zqfkxhswcgyquzdxscnlhqxukujzwngt/92.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/0.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/14.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/21.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/28.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/35.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/42.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/49.png
#   inflating: reface-fake-detection-result/train/zqfpketaqjgoolrkcphfrvfdmdgvydab/7.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/0.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/14.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/19.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/24.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/29.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/34.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/4.png
#   inflating: reface-fake-detection-result/train/zqgcshyazqzedtqbujhruxcsnqneefps/9.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/0.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/102.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/123.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/144.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/20.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/41.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/61.png
#   inflating: reface-fake-detection-result/train/zqgwdenjuxrtqahoeszfagnfmhopnhla/82.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/0.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/18.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/27.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/36.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/45.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/54.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/64.png
#   inflating: reface-fake-detection-result/train/zqhxestbtnbhzgvqwtcztyftksxwpzvu/9.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/0.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/13.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/18.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/22.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/27.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/32.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/4.png
#   inflating: reface-fake-detection-result/train/zqipfabhnjorzbezfyraidvatvldxnoy/9.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/0.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/12.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/15.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/18.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/22.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/3.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/6.png
#   inflating: reface-fake-detection-result/train/zqjzrxdljzdmyxbvyolqhqjeaizpjtiv/9.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/0.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/12.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/18.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/24.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/30.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/36.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/43.png
#   inflating: reface-fake-detection-result/train/zqlmmzthgepuvdtsyatwyjcbckftqujc/6.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/0.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/14.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/19.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/24.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/29.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/34.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/4.png
#   inflating: reface-fake-detection-result/train/zqlnatmznexrdmnfldrjqajayqeazmlr/9.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/0.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/111.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/133.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/156.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/22.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/44.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/66.png
#   inflating: reface-fake-detection-result/train/zqmdwfqnlhxncmarjtskcyaktztlqylq/89.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/0.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/11.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/14.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/18.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/22.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/26.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/3.png
#   inflating: reface-fake-detection-result/train/zqneautwtkcaajkgaumoebuuhxfzozio/7.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/0.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/170.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/256.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/341.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/427.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/512.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/598.png
#   inflating: reface-fake-detection-result/train/zqngxcvcavaliaddflkyiljzxzybtqgj/85.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/0.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/11.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/17.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/22.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/28.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/34.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/40.png
#   inflating: reface-fake-detection-result/train/zqnqkgpdopjdvwywzqzpuxmtqvxvjvtb/5.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/0.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/14.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/18.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/23.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/28.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/33.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/4.png
#   inflating: reface-fake-detection-result/train/zqnsykaaufxmkgmmfnusqxntoctiohgh/9.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/0.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/13.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/17.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/22.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/26.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/31.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/4.png
#   inflating: reface-fake-detection-result/train/zqobuczhaozlygqtwzsixdmqhumkqyje/8.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/0.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/15.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/22.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/30.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/37.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/45.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/53.png
#   inflating: reface-fake-detection-result/train/zqpgdxdobsgaawmkospttgzzbijhvqhe/7.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/0.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/11.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/14.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/18.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/22.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/26.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/3.png
#   inflating: reface-fake-detection-result/train/zqplszbwmdcvezkjhfqjhrwizpfgxhom/7.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/0.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/109.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/136.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/163.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/191.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/27.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/54.png
#   inflating: reface-fake-detection-result/train/zqpnlvjdlahzyjzmvtavjblaeycckjnq/81.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/0.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/0_2.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/10.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/10_2.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/10_3.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/12.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/15.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/2.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/4.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/4_2.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/6.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/6_2.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/8.png
#   inflating: reface-fake-detection-result/train/zqqabyyqeipqzbgxwiixfzjxnxsvnboh/8_2.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/0.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/12.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/15.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/18.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/22.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/3.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/6.png
#   inflating: reface-fake-detection-result/train/zqqfzemihtyjtabzfaohnjiolqfqhcko/9.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/0.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/12.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/16.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/20.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/24.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/28.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/4.png
#   inflating: reface-fake-detection-result/train/zqqusmztlkhyfzrqwjblxpxomwbytxmk/8.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/0.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/11.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/14.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/17.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/2.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/20.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/5.png
#   inflating: reface-fake-detection-result/train/zqrrsveyeubefrfkehpmscaviaywmzub/8.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/0.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/10.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/21.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/32.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/42.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/53.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/64.png
#   inflating: reface-fake-detection-result/train/zqrvaptxuapodatpqorupfpikkzzulgh/75.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/0.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/101.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/121.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/142.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/20.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/40.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/60.png
#   inflating: reface-fake-detection-result/train/zqsefnuvlheyzsobtqdeueyushnuuyms/81.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/0.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/114.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/133.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/19.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/38.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/57.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/76.png
#   inflating: reface-fake-detection-result/train/zqsnyoafatbfymmchjjicrtxvcnpxaib/95.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/0.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/10.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/14.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/17.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/21.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/25.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/3.png
#   inflating: reface-fake-detection-result/train/zqssmyibsndfnujfurttziplluqejlom/7.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/0.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/11.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/22.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/33.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/45.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/56.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/67.png
#   inflating: reface-fake-detection-result/train/zqtonmwjlncfdtrlffkfzrlcauomaury/79.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/0.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/10.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/15.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/20.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/25.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/30.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/36.png
#   inflating: reface-fake-detection-result/train/zqtsducamcqlghrnbuexgzhghurximfr/5.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/0.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/11.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/17.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/22.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/28.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/34.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/40.png
#   inflating: reface-fake-detection-result/train/zqurhgbcdjtehpzasoofzhqyqkjprwkv/5.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/0.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/14.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/19.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/24.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/29.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/34.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/4.png
#   inflating: reface-fake-detection-result/train/zqutqqkiosgvkzejedrnclykbptxgwip/9.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/0.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/106.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/124.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/17.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/35.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/53.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/70.png
#   inflating: reface-fake-detection-result/train/zquvdtntvtabmotpkxeenlytpgmwwxab/88.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/0.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/17.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/25.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/34.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/42.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/51.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/60.png
#   inflating: reface-fake-detection-result/train/zqvaroalrgladqlyjbzgqsdboogvjvwp/8.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/0.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/12.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/24.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/36.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/48.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/60.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/72.png
#   inflating: reface-fake-detection-result/train/zqvfelfqdozlrijpswabnuaqirectzuz/85.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/0.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/11.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/17.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/23.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/29.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/35.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/41.png
#   inflating: reface-fake-detection-result/train/zqvipzpbrwlyrfohixklxpiblxtulzmz/5.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/0.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/16.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/25.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/33.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/42.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/50.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/59.png
#   inflating: reface-fake-detection-result/train/zqvluzhkrhijfvliphlwnyvqjlqsgwky/8.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/0.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/12.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/16.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/20.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/24.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/29.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/4.png
#   inflating: reface-fake-detection-result/train/zqvxjuhhcwlarfkdjemjumljfnjjqgju/8.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/0.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/0_2.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/0_3.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/159.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/238.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/318.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/318_2.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/397.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/477.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/477_2.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/557.png
#   inflating: reface-fake-detection-result/train/zqxlkwmvxbqmniyoyhvohvulsjikzzxt/79.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/0.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/17.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/26.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/35.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/44.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/53.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/62.png
#   inflating: reface-fake-detection-result/train/zqxmzwgnjqemtcdnqlxchlssxkxsgjnv/8.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/0.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/10.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/15.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/20.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/25.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/30.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/35.png
#   inflating: reface-fake-detection-result/train/zqyykhgsauyhmshavfuaqechixshbqnn/5.png
#   inflating: reface-fake-detection-result/train/zqzdvxlkaheiiimkxdmzsfloatkcvxho/0.png
#   inflating: reface-fake-detection-result/train/zqzdvxlkaheiiimkxdmzsfloatkcvxho/13.png
#   inflating: reface-fake-detection-result/train/zqzdvxlkaheiiimkxdmzsfloatkcvxho/26.png
#   inflating: reface-fake-detection-result/train/zqzdvxlkaheiiimkxdmzsfloatkcvxho/39.png
#   inflating: reface-fake-detection-result/train/zqzdvxlkaheiiimkxdmzsfloatkcvxho/52.png
#   inflating: reface-fake-detection-result/train/zqzdvxlkaheiiimkxdmzsfloatkcvxho/65.png
#   inflating: reface-fake-detection-result/train/zqzdvxlkaheiiimkxdmzsfloatkcvxho/78.png
# ...
#   inflating: reface-fake-detection-result/train/zzritnaywwhiuhryuthxmilrytaphcjx/24.png
#   inflating: reface-fake-detection-result/train/zzritnaywwhiuhryuthxmilrytaphcjx/29.png
#   inflating: reface-fake-detection-result/train/zzritnaywwhiuhryuthxmilrytaphcjx/4.png
#   inflating: reface-fake-detection-result/train/zzritnaywwhiuhryuthxmilrytaphcjx/8.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/0.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/12.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/14.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/17.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/2.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/4.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/7.png
#   inflating: reface-fake-detection-result/train/zzrjlfedsmhzrrdgnmaoxlgslntmviix/9.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/0.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/10.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/15.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/21.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/26.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/31.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/37.png
#   inflating: reface-fake-detection-result/train/zzrmgbubajcxanjhnuvrynbudlfsnrud/5.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/0.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/15.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/23.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/30.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/38.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/46.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/54.png
#   inflating: reface-fake-detection-result/train/zzsjeithkfslrmkzjuklpybmrjufpjaz/7.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/0.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/18.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/27.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/37.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/46.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/55.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/65.png
#   inflating: reface-fake-detection-result/train/zztcleeiedxwsqacwhxvoizitqbmxghv/9.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/0.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/113.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/226.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/339.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/453.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/566.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/679.png
#   inflating: reface-fake-detection-result/train/zztkmwrpgzzmfuawonllmlvfshjgisqr/793.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/0.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/12.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/17.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/21.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/25.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/30.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/4.png
#   inflating: reface-fake-detection-result/train/zztncmggmplypwtehckkoeudxjakqqrb/8.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/0.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/122.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/147.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/172.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/24.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/49.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/73.png
#   inflating: reface-fake-detection-result/train/zztxwzjtkjmlunljgxgkkmicxxxmhnep/98.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/0.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/12.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/17.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/21.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/25.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/30.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/4.png
#   inflating: reface-fake-detection-result/train/zzumzvyyanyxtgeggdawkzmscvhkpaig/8.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/0.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/12.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/16.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/20.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/24.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/28.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/4.png
#   inflating: reface-fake-detection-result/train/zzuuqxqumlfkmqpgkqgpaqypfvfqahqf/8.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/0.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/18.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/27.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/36.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/45.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/54.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/63.png
#   inflating: reface-fake-detection-result/train/zzwcravtsmhdokvxeomwnojpfyddjjhl/9.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/0.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/10.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/16.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/21.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/27.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/32.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/38.png
#   inflating: reface-fake-detection-result/train/zzwdiifidotmasjelmklpjvwvvkkcttr/5.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/0.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/13.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/17.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/22.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/26.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/31.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/4.png
#   inflating: reface-fake-detection-result/train/zzwfhnuwnwjiakqpxykrluyhvlvebcnh/8.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/0.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/0_2.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/10.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/13.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/13_2.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/17.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/20.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/20_2.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/24.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/3.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/3_2.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/6.png
#   inflating: reface-fake-detection-result/train/zzwrcfesnqcbnptvjdimgoeoeshvsqlh/6_2.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/0.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/12.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/18.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/24.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/30.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/36.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/43.png
#   inflating: reface-fake-detection-result/train/zzwucrroscqqtsiqnqdkbpcpgomdzftw/6.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/0.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/0_2.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/10.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/10_2.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/13.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/13_2.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/17.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/17_2.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/20.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/20_2.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/24.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/24_2.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/3.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/3_2.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/6.png
#   inflating: reface-fake-detection-result/train/zzxaeygpiabnmvidwgjuslgyexvdbgmb/6_2.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/0.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/14.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/21.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/28.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/35.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/42.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/50.png
#   inflating: reface-fake-detection-result/train/zzxelbklyoxiqcewlxyhacnwwqvzxolr/7.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/0.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/119.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/139.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/19.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/39.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/59.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/79.png
#   inflating: reface-fake-detection-result/train/zzydmfoicpfrzluhnvsdlvwjzisjdkhe/99.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/0.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/112.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/16.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/32.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/48.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/64.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/80.png
#   inflating: reface-fake-detection-result/train/zzyfcevidrqtiwskzzyphajnvspnidai/96.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/0.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/13.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/27.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/40.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/54.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/67.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/81.png
#   inflating: reface-fake-detection-result/train/zzzclndnuhhfsdyyottrqadkselbfbjy/95.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/0.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/101.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/121.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/142.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/20.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/40.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/60.png
#   inflating: reface-fake-detection-result/train/zzzwigxvidvwmrzulrfmaabckbqyeujs/81.png

# %%
# !pip install -qq av
# !pip install -qq torchsummary
# !pip install -qq linformer
# !pip install -qq vit_pytorch
# Out:
#      |████████████████████████████████| 37.2 MB 1.2 MB/s

# %%
# !pip install -qq albumentations==1.1.0

# %%
# !pip install facenet-pytorch > /dev/null 2>&1
# !apt install zip > /dev/null 2>&1

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !nvidia-smi
# Out:
# Sat Nov  6 22:08:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !rm -rf reface-fake-detection tmp

# %%
# !cp -R /content/drive/MyDrive/dl-creator-school/reface-fake-detection reface-fake-detection

# %%
# !rsync -r --info=progress2 /content/drive/MyDrive/dl-creator-school/reface-fake-detection reface-fake-detection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/dl-creator-school/
# Out:
# reface-fake-detection-result.tar.gz

# %% [markdown]
# ## Modules importing

# %%
import os
import glob
import json
import cv2
import multiprocessing as mp

import pandas as pd
import numpy as np

import torch
import torch.nn.functional as F
import torchvision

from torch import nn, optim
from torch.utils.data import sampler, DataLoader, Dataset
from torch.optim.lr_scheduler import MultiStepLR, CosineAnnealingLR, ReduceLROnPlateau, StepLR
from torch.utils import data
from torchvision import transforms, models
from torchvision.models import resnet101
from torchsummary import summary

from albumentations import Normalize, Compose, Resize, CenterCrop, HorizontalFlip, Rotate, VerticalFlip, RandomCrop, Downscale, RandomBrightnessContrast, GaussianBlur, HueSaturationValue
from albumentations.pytorch import ToTensorV2

from facenet_pytorch import MTCNN, InceptionResnetV1, fixed_image_standardization, training

from linformer import Linformer
from vit_pytorch.efficient import ViT

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

from PIL import Image
from tqdm.notebook import tqdm

from typing import List, Dict, Tuple, Union, Optional
from pathlib import Path

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.dpi'] = 150

# %% [markdown]
# ## Settings

# %%
if torch.cuda.is_available():
    device = 'cuda:0'
#     torch.set_default_tensor_type('torch.cuda.FloatTensor')
#     torch.multiprocessing.set_start_method('spawn')
else:
    device = 'cpu'
print(f'Running on device: {device}')
# Out:
# Running on device: cuda:0

# %%
# !ls ../input/reface-fake-det-faces

# %%
PATH2PROJECT = Path('')
PATH2DRIVE = Path('/content/drive/MyDrive/dl-creator-school/')

PATH2DATA = PATH2PROJECT / 'reface-fake-detection-result'
PATH2TRAIN = PATH2DATA / 'train'
PATH2TEST = PATH2DATA / 'test'
PATH2SUBMISSIONS = Path('') / 'submissions'
PATH2CHECKOUTS = Path('') / 'checkouts'

# %%
try: PATH2SUBMISSIONS.mkdir()
except: pass
try: PATH2CHECKOUTS.mkdir()
except: pass

# %%
SEED = 42
VAL_SIZE = 0.2

# %%
N_FACES = 6

BATCH_SIZE = 32
NUM_WORKERS = mp.cpu_count()

WARM_UP_EPOCHS = 5
WARM_UP_LR = 3e-3
FINE_TUNE_EPOCHS = 20
FINE_TUNE_LR = 5e-4

H, W = 112, 112 #224, 224
DELTA = 10
MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]

THRESHOLD = 0.5
EPSILON = 1e-7

# %% [markdown]
# ## Training metadata

# %%
meta_df = pd.read_csv(PATH2DATA / 'train.csv')
meta_df.shape
# Out:
# (41161, 2)

# %%
meta_df.label.value_counts(normalize=True)
# Out:
# 0    0.658706
# 1    0.341294
# Name: label, dtype: float64

# %%
meta_df['path'] = meta_df['filename'].apply(lambda x: str(PATH2TRAIN / x.split('.')[0]))

# %%
meta_df.sample(n=5, random_state=SEED)
# Out:
#                                    filename  ...                                               path
# 12469  dnmwxnsqazhbrzbwhcyeeitekhssbmmx.mp4  ...  reface-fake-detection-result/train/dnmwxnsqazh...
# 16106  mjfvkdjclgbgbeikregomzvancvoyien.mp4  ...  reface-fake-detection-result/train/mjfvkdjclgb...
# 144    pbjvfdegxlmysnyelopgwdqglzjgheep.mp4  ...  reface-fake-detection-result/train/pbjvfdegxlm...
# 6442   rwecopvulhnwevpzsfupgdzwdjfenmcr.mp4  ...  reface-fake-detection-result/train/rwecopvulhn...
# 39989  bvchibtmrvczfpytenatbaqvbulkjbve.mp4  ...  reface-fake-detection-result/train/bvchibtmrvc...
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Clean data

# %% [markdown]
# ### Remove corrupt videos or ones in what cannot detect any faces

# %%
meta_df = meta_df[meta_df['path'].map(lambda x: os.path.exists(x))]
meta_df.shape
# Out:
# (41150, 3)

# %% [markdown]
# ### Remove videos in which do not have enough faces

# %%
# try:
#     valid_meta_df = pd.read_csv(PATH2PROJECT / 'trainreface' / 'valid_meta_df.csv')
# except:
valid_meta_df = pd.DataFrame(columns=['filename', 'label', 'path'])
r = []
# for row_idx, row in tqdm(train_df.iterrows()):
for row_idx in tqdm(meta_df.index):
    row = meta_df.loc[row_idx]
    img_dir = row['path']
    face_paths = glob.glob(f'{img_dir}/*.png')

    if len(face_paths) >= 4: # Satisfy the minimum requirement for the number of faces
        r.append(row)

valid_meta_df = valid_meta_df.append(r, ignore_index=True)
# valid_meta_df.to_csv(PATH2PROJECT / 'trainreface' / 'valid_meta_df.csv', index=False)
valid_meta_df.shape
# Out:
#   0%|          | 0/41150 [00:00<?, ?it/s]
# (41121, 3)

# %%
valid_meta_df.head()
# Out:
#                                filename  ...                                               path
# 0  zgwcwwfkkpmjlwvxbeiwynrkkfoesygm.mp4  ...  reface-fake-detection-result/train/zgwcwwfkkpm...
# 1  rbnejlayjtkoivhofhdtohqxxjqqmsuj.mp4  ...  reface-fake-detection-result/train/rbnejlayjtk...
# 2  fuycvyzuvyfojsiqnftqnhtoxxaziype.mp4  ...  reface-fake-detection-result/train/fuycvyzuvyf...
# 3  lgzrgjaolrygyhnvbnpctbavufisuohx.mp4  ...  reface-fake-detection-result/train/lgzrgjaolry...
# 4  owjbgxusijaajvrphsmaskohuzhkxlgl.mp4  ...  reface-fake-detection-result/train/owjbgxusija...
#
# [5 rows x 3 columns]

# %%
# valid_meta_df.path = valid_meta_df.path.apply(lambda x: '../input/reface-fake-det-faces/'+x.split('reface-fake-detection/')[-1])

# %%
folders = os.listdir(PATH2TEST)
X_test = pd.DataFrame({'path': [str(PATH2TEST/folder) for folder in folders], 'filename': folders})
len(X_test)
# Out:
# 17791

# %%
submission = pd.read_csv(PATH2PROJECT / 'sample_submission.csv')
submission.shape
# Out:
# (17794, 2)

# %%
submission['path'] = submission['filename'].apply(lambda x: str(PATH2TEST/x.split('.')[0]))

# %% [markdown]
# ## Stratified split data on test and validation

# %%
X_train, X_val, y_train, y_val = train_test_split(
    valid_meta_df['path'].to_numpy(),
    valid_meta_df['label'].to_numpy(),
    test_size=VAL_SIZE,
    random_state=SEED, 
    stratify=valid_meta_df['label']
)

# %%
np.mean(y_train), np.mean(y_val)
# Out:
# (0.34125729571984437, 0.34127659574468083)

# %%
assert not set(X_train.tolist()) & set(X_val.tolist()), 'intersection is not empty'

# %% [markdown]
# ## Helper functions

# %%
def calculate_f1(preds, labels):
    '''
    Parameters:
        preds: The predictions.
        labels: The labels.

    Returns:
        f1 score
    '''
    return f1_score(labels, (np.array(preds) >= THRESHOLD).astype(np.uint8), average='micro')


def train_the_model(
    model,
    criterion,
    optimizer,
    scheduler,
    epochs,
    train_dataloader,
    val_dataloader,
    best_val_loss=1e7,
):
    '''
    Parameters:
        model: The model needs to be trained.
        criterion: Loss function.
        optimizer: The optimizer.
        epochs: The number of epochs
        train_dataloader: The dataloader used to generate training samples.
        val_dataloader: The dataloader used to generate validation samples.
        best_val_loss: The initial value of the best val loss (default: 1e7.)

    Returns:
        losses: All computed losses.
        val_losses: All computed val_losses.
        loglosses: All computed loglosses.
        f1_scores: All computed f1_scores.
        val_f1_scores: All computed val_f1_scores.
        best_val_loss: New value of the best val loss.
        best_model_state_dict: The state_dict of the best model.
        best_optimizer_state_dict: The state_dict of the optimizer corresponds to the best model.
    '''

    losses = np.zeros(epochs)
    val_losses = np.zeros(epochs)
    f1_scores = np.zeros(epochs)
    val_f1_scores = np.zeros(epochs)
    best_model_state_dict = None
    best_optimizer_state_dict = None

    for i in tqdm(range(epochs)):
        batch_losses = []
        train_pbar = tqdm(train_dataloader)
        train_pbar.desc = f'Epoch {i+1}'
        classifier.train()

        all_labels = []
        all_preds = []

        for i_batch, sample_batched in enumerate(train_pbar):
            # Zero gradients
            optimizer.zero_grad()
            
            # Make prediction.
            y_pred = classifier(sample_batched['faces'].to(device))

            all_labels.extend(sample_batched['label'].numpy().tolist())
            all_preds.extend(y_pred.squeeze(dim=-1).detach().cpu().numpy().tolist())

            # Compute loss.
            loss = criterion(y_pred, sample_batched['label'].to(device))
            batch_losses.append(loss.item())

            # Perform a backward pass, and update the weights.
            loss.backward()
            optimizer.step()

            # Display some information in progress-bar.
            train_pbar.set_postfix({
                'loss': batch_losses[-1]
            })

        # Compute scores.
        f1_scores[i] = calculate_f1(all_preds, all_labels)

        # Compute batch loss (average).
        losses[i] = np.array(batch_losses).mean()


        # Compute val loss
        val_batch_losses = []
        val_pbar = tqdm(val_dataloader)
        val_pbar.desc = 'Validating'
        classifier.eval()

        all_labels = []
        all_preds = []

        for i_batch, sample_batched in enumerate(val_pbar):
            # Make prediction.            
            y_pred = classifier(sample_batched['faces'].to(device))

            all_labels.extend(sample_batched['label'].numpy().tolist())
            all_preds.extend(y_pred.squeeze(dim=-1).detach().cpu().numpy().tolist())

            # Compute val loss.
            val_loss = criterion(y_pred, sample_batched['label'].to(device))
            val_batch_losses.append(val_loss.item())

            # Display some information in progress-bar.
            val_pbar.set_postfix({
                'val_loss': val_batch_losses[-1]
            })

        # Compute val scores.
        val_f1_scores[i] = calculate_f1(all_preds, all_labels)

        val_losses[i] = np.array(val_batch_losses).mean()
        print(f'loss: {losses[i]} | val loss: {val_losses[i]} | f1: {f1_scores[i]} | val f1: {val_f1_scores[i]}')
        
        # step of lr scheduler
        scheduler.step(val_losses[i])
        
        # Update the best values
        if val_losses[i] < best_val_loss:
            best_val_loss = val_losses[i]
            
            print('Found a better checkpoint!')
            best_model_state_dict = classifier.state_dict()
            best_optimizer_state_dict = optimizer.state_dict()
            state = {
                'state_dict': best_model_state_dict,
                'warmup_optimizer': best_optimizer_state_dict,
                'best_val_loss': best_val_loss,
            }
            torch.save(state, 'best-checkout.pth')
            
    return losses, val_losses, f1_scores, val_f1_scores, best_val_loss, best_model_state_dict, best_optimizer_state_dict


def visualize_results(
    losses,
    val_losses,
    f1_scores,
    val_f1_scores
):
    '''
    Parameters:
        losses: A list of losses.
        val_losses: A list of val losses.
        f1_scores: A list of f1 scores.
        val_f1_scores: A list of val f1 scores.
    '''

    fig = plt.figure(figsize=(16, 8))
    ax = fig.add_axes([0, 0, 1, 1])

    ax.plot(np.arange(1, len(losses) + 1), losses)
    ax.plot(np.arange(1, len(val_losses) + 1), val_losses)
    ax.set_xlabel('epoch', fontsize='xx-large')
    ax.set_ylabel('loss', fontsize='xx-large')
    ax.legend(
        ['loss', 'val loss'],
        loc='upper right',
        fontsize='xx-large',
        shadow=True
    )
    plt.show()

    fig = plt.figure(figsize=(16, 8))
    ax = fig.add_axes([0, 0, 1, 1])

    ax.plot(np.arange(1, len(f1_scores) + 1), f1_scores)
    ax.plot(np.arange(1, len(val_f1_scores) + 1), val_f1_scores)
    ax.set_xlabel('epoch', fontsize='xx-large')
    ax.set_ylabel('f1 score', fontsize='xx-large')
    ax.legend(
        ['f1', 'val f1'],
        loc='upper left',
        fontsize='xx-large',
        shadow=True
    )
    plt.show()

# %% [markdown]
# ## Dataset and Dataloaders

# %%
class FaceDataset(Dataset):
    def __init__(self, img_dirs, labels, n_faces=1, preprocess=None):
        self.img_dirs = img_dirs
        self.labels = labels
        self.n_faces = n_faces
        self.preprocess = preprocess

    def __len__(self):
        return len(self.img_dirs)
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_dir = self.img_dirs[idx]
        label = self.labels[idx]
        face_paths = glob.glob(f'{img_dir}/*.png')

        if len(face_paths) >= self.n_faces:
            sample = sorted(np.random.choice(face_paths, self.n_faces, replace=False))
        else:
            sample = sorted(np.random.choice(face_paths, self.n_faces, replace=True))
            
        faces = []
        for face_path in sample:
            face = cv2.imread(face_path, 1)
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            faces.append(face)
            
        if self.preprocess is not None:
            d = {f'image{i-1}': faces[i] for i in range(1, self.n_faces)}
            d['image'] = faces[0]
            faces = list(self.preprocess(**d).values())

        return {'faces': torch.stack(faces).permute(1, 0, 2, 3), 'label': torch.tensor([label], dtype=torch.float)}#{'faces': np.concatenate(faces, axis=-1).transpose(2, 0, 1), 'label': np.array([label], dtype=float)}

# %%
train_transforms = Compose([
    Resize(H+DELTA, W+DELTA),
    # Downscale(scale_min=0.5, scale_max=0.9, p=0.3),
    RandomCrop(H, W),
    HorizontalFlip(p=0.5),
    RandomBrightnessContrast(brightness_limit=0, contrast_limit=0.2, p=0.3),
    HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.3),
    GaussianBlur(blur_limit=(3, 7), p=0.3),
    Normalize(mean=MEAN, std=STD, p=1),
    ToTensorV2()
], additional_targets={f'image{i}': 'image' for i in range(0, N_FACES-1)})

val_transforms = Compose([
    Resize(H+DELTA, W+DELTA),
    CenterCrop(H, W),
    Normalize(mean=MEAN, std=STD, p=1),
    ToTensorV2()
], additional_targets={f'image{i}': 'image' for i in range(0, N_FACES-1)})

test_transforms = Compose([
    Resize(H+DELTA, W+DELTA),
    CenterCrop(H, W),
    Normalize(mean=MEAN, std=STD, p=1),
    ToTensorV2()
], additional_targets={f'image{i}': 'image' for i in range(0, N_FACES-1)})

# %%
train_dataset = FaceDataset(
    img_dirs=X_train,
    labels=y_train,
    n_faces=N_FACES,
    preprocess=train_transforms
)
val_dataset = FaceDataset(
    img_dirs=X_val,
    labels=y_val,
    n_faces=N_FACES,
    preprocess=val_transforms
)
test_dataset = FaceDataset(
    img_dirs=X_test['path'].values,
    labels=[0]*len(X_test['path']),
    n_faces=N_FACES,
    preprocess=test_transforms
)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
#     generator=torch.Generator(device='cuda'),
#     num_workers=0,
#     pin_memory=False,
)
val_dataloader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
#     generator=torch.Generator(device='cuda'),
#     num_workers=0,
#     pin_memory=False,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
#     generator=torch.Generator(device='cuda'),
#     num_workers=0,
#     pin_memory=False,
)

# %%
plt.figure(figsize=(10,10))
for ii,img in enumerate(next(iter(train_dataloader))['faces'][0].permute(1, 0, 2, 3)):
    plt.subplot(2,2,ii+1)
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = img.numpy().transpose((1, 2, 0))
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if ii == 3:
        break

# %%
next(iter(train_dataloader))['faces'].shape
# Out:
# torch.Size([32, 3, 6, 112, 112])

# %%
# next(iter(train_dataloader))['faces'].permute(0, 2, 1, 3, 4).shape

# %% [markdown]
# ## Models

# %%
class DeepfakeClassifierResnet(nn.Module):
    def __init__(self, encoder, in_channels=3, out_channels=64, kernel_size=7, stride=2, padding=3, bias=False, linear_size=2048, num_classes=1):
        super(DeepfakeClassifierResnet, self).__init__()
        self.encoder = encoder
        
        # Modify input layer.
        self.encoder.conv1 = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size=kernel_size,
            stride=stride,
            padding=padding,
            bias=bias,
        )
        
        # Modify output layer.
#         self.encoder.fc = nn.Sequential(
#             nn.BatchNorm1d(linear_size), 
#             nn.Dropout(p=0.25), # 
#             nn.Linear(in_features=linear_size, out_features=2048),
#             nn.ReLU(),
#             nn.BatchNorm1d(2048, eps=1e-05, momentum=0.1),
#             nn.Dropout(p=0.5),
#             nn.Linear(in_features=2048, out_features=num_classes)
#         )
        self.encoder.fc = nn.Linear(linear_size * 1, num_classes)

    def forward(self, x):
        return torch.sigmoid(self.encoder(x))
    
    def freeze_all_layers(self):
        for param in self.encoder.parameters():
            param.requires_grad = False

    def freeze_middle_layers(self):
        self.freeze_all_layers()
        
        for param in self.encoder.conv1.parameters():
            param.requires_grad = True
            
        for param in self.encoder.fc.parameters():
            param.requires_grad = True

    def unfreeze_all_layers(self):
        for param in self.encoder.parameters():
            param.requires_grad = True

# %%
class DeepfakeClassifierInception(nn.Module):
    def __init__(self, encoder, in_channels=3, out_channels=32, kernel_size=3, stride=2, padding=3, bias=False, linear_size=512, num_classes=1):
        super(DeepfakeClassifierInception, self).__init__()
        self.encoder = encoder
        
        # Modify input layer.
        self.encoder.conv2d_1a.conv = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size=kernel_size,
            stride=stride,
            padding=padding,
            bias=bias,
        )
        
        # Modify output layer.
#         self.encoder.logits = nn.Sequential(
#             nn.BatchNorm1d(linear_size), 
#             nn.Dropout(p=0.25), # 
#             nn.Linear(in_features=linear_size, out_features=2048),
#             nn.ReLU(),
#             nn.BatchNorm1d(2048, eps=1e-05, momentum=0.1),
#             nn.Dropout(p=0.5),
#             nn.Linear(in_features=2048, out_features=num_classes)
#         )
        self.encoder.logits = nn.Linear(linear_size * 1, num_classes)

    def forward(self, x):
        return torch.sigmoid(self.encoder(x))
    
    def freeze_all_layers(self):
        for param in self.encoder.parameters():
            param.requires_grad = False

    def freeze_middle_layers(self):
        self.freeze_all_layers()
        
        for param in self.encoder.conv2d_1a.conv.parameters():
            param.requires_grad = True
            
        for param in self.encoder.logits.parameters():
            param.requires_grad = True

    def unfreeze_all_layers(self):
        for param in self.encoder.parameters():
            param.requires_grad = True

# %%
class DeepfakeClassifierR3D18(nn.Module):
    def __init__(self, encoder, linear_size=512, num_classes=1):
        super(DeepfakeClassifierR3D18, self).__init__()
        self.encoder = encoder
        
        # Modify output layer.
        num_features = self.encoder.fc.in_features
        self.encoder.fc = nn.Linear(num_features, num_classes)
#         self.encoder.fc = nn.Sequential(
#             nn.BatchNorm1d(linear_size), 
#             nn.Dropout(p=0.25), # 
#             nn.Linear(in_features=linear_size, out_features=2048),
#             nn.ReLU(),
#             nn.BatchNorm1d(2048, eps=1e-05, momentum=0.1),
#             nn.Dropout(p=0.5),
#             nn.Linear(in_features=2048, out_features=num_classes)
#         )

#         self.encoder.logits = nn.Linear(linear_size * 1, num_classes)

    def forward(self, x):
        return torch.sigmoid(self.encoder(x))
    
    def freeze_all_layers(self):
        for param in self.encoder.parameters():
            param.requires_grad = False

    def freeze_middle_layers(self):
        self.freeze_all_layers()
            
        for param in self.encoder.fc.parameters():
            param.requires_grad = True

    def unfreeze_all_layers(self):
        for param in self.encoder.parameters():
            param.requires_grad = True

# %%
class FocalLoss(nn.Module):
    def __init__(self, gamma=2, sample_weight=None):
        super().__init__()
        self.gamma = gamma
        self.sample_weight = sample_weight

    def forward(self, logit, target):
        target = target.float()
        max_val = (-logit).clamp(min=0)
        loss = logit - logit * target + max_val + \
               ((-max_val).exp() + (-logit - max_val).exp()).log()

        invprobs = F.logsigmoid(-logit * (target * 2.0 - 1.0))
        loss = (invprobs * self.gamma).exp() * loss
        if len(loss.size())==2:
            loss = loss.sum(dim=1)
        if self.sample_weight is not None:
            loss = loss * self.sample_weight
        return loss.mean()

# %%
# efficient_transformer = Linformer(
#     dim=128,
#     seq_len=49+1,  # 7x7 patches + 1 cls-token
#     depth=12,
#     heads=8,
#     k=64
# )

# classifier = ViT(
#     dim=128,
#     image_size=224,
#     patch_size=32,
#     num_classes=1,
#     transformer=efficient_transformer,
#     channels=3,
# ).to(device)
# classifier.train()

# %%
encoder_r3d_18 = models.video.r3d_18(
    pretrained=True,
)

classifier = DeepfakeClassifierR3D18(encoder=encoder_r3d_18, linear_size=512, num_classes=1)

classifier.to(device);
classifier.train();

# %%
# x = torch.zeros(1, 3, N_FACES, H, W)
# y= classifier(x)
# print(y.shape)

# %%
# encoder_facenet = InceptionResnetV1(
#     classify=True,
#     pretrained='casia-webface',
#     num_classes=1
# )

# classifier = DeepfakeClassifierInception(encoder=encoder_facenet, in_channels=3*N_FACES, num_classes=1)

# classifier.to(device);
# classifier.train();

# %%
# encoder_resnet = resnet101(pretrained=True)

# classifier = DeepfakeClassifierResnet(encoder=encoder_resnet, in_channels=3*N_FACES, num_classes=1)

# classifier.to(device);
# classifier.train();

# %%
criterion = nn.BCELoss()#FocalLoss()

# %%
losses = np.zeros(WARM_UP_EPOCHS + FINE_TUNE_EPOCHS)
val_losses = np.zeros(WARM_UP_EPOCHS + FINE_TUNE_EPOCHS)
f1_scores = np.zeros(WARM_UP_EPOCHS + FINE_TUNE_EPOCHS)
val_f1_scores = np.zeros(WARM_UP_EPOCHS + FINE_TUNE_EPOCHS)

best_val_loss = 1e7

# %% [markdown]
# ## Define training hyperparameters

# %%
classifier.freeze_middle_layers()
warmup_optimizer = optim.Adam(filter(lambda p: p.requires_grad, classifier.parameters()), lr=WARM_UP_LR)
warmup_scheduler = ReduceLROnPlateau(warmup_optimizer, mode='min', factor=0.1, patience=5, threshold=0.0001, threshold_mode='abs', verbose=True)

# %%
summary(classifier, input_size=(3, N_FACES, H, W))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1        [-1, 64, 6, 56, 56]          28,224
#        BatchNorm3d-2        [-1, 64, 6, 56, 56]             128
#               ReLU-3        [-1, 64, 6, 56, 56]               0
#       Conv3DSimple-4        [-1, 64, 6, 56, 56]         110,592
#        BatchNorm3d-5        [-1, 64, 6, 56, 56]             128
#               ReLU-6        [-1, 64, 6, 56, 56]               0
#       Conv3DSimple-7        [-1, 64, 6, 56, 56]         110,592
#        BatchNorm3d-8        [-1, 64, 6, 56, 56]             128
#               ReLU-9        [-1, 64, 6, 56, 56]               0
#        BasicBlock-10        [-1, 64, 6, 56, 56]               0
#      Conv3DSimple-11        [-1, 64, 6, 56, 56]         110,592
#       BatchNorm3d-12        [-1, 64, 6, 56, 56]             128
#              ReLU-13        [-1, 64, 6, 56, 56]               0
#      Conv3DSimple-14        [-1, 64, 6, 56, 56]         110,592
#       BatchNorm3d-15        [-1, 64, 6, 56, 56]             128
#              ReLU-16        [-1, 64, 6, 56, 56]               0
#        BasicBlock-17        [-1, 64, 6, 56, 56]               0
#      Conv3DSimple-18       [-1, 128, 3, 28, 28]         221,184
#       BatchNorm3d-19       [-1, 128, 3, 28, 28]             256
#              ReLU-20       [-1, 128, 3, 28, 28]               0
#      Conv3DSimple-21       [-1, 128, 3, 28, 28]         442,368
#       BatchNorm3d-22       [-1, 128, 3, 28, 28]             256
#            Conv3d-23       [-1, 128, 3, 28, 28]           8,192
#       BatchNorm3d-24       [-1, 128, 3, 28, 28]             256
#              ReLU-25       [-1, 128, 3, 28, 28]               0
#        BasicBlock-26       [-1, 128, 3, 28, 28]               0
#      Conv3DSimple-27       [-1, 128, 3, 28, 28]         442,368
#       BatchNorm3d-28       [-1, 128, 3, 28, 28]             256
#              ReLU-29       [-1, 128, 3, 28, 28]               0
#      Conv3DSimple-30       [-1, 128, 3, 28, 28]         442,368
#       BatchNorm3d-31       [-1, 128, 3, 28, 28]             256
#              ReLU-32       [-1, 128, 3, 28, 28]               0
#        BasicBlock-33       [-1, 128, 3, 28, 28]               0
#      Conv3DSimple-34       [-1, 256, 2, 14, 14]         884,736
#       BatchNorm3d-35       [-1, 256, 2, 14, 14]             512
#              ReLU-36       [-1, 256, 2, 14, 14]               0
#      Conv3DSimple-37       [-1, 256, 2, 14, 14]       1,769,472
#       BatchNorm3d-38       [-1, 256, 2, 14, 14]             512
#            Conv3d-39       [-1, 256, 2, 14, 14]          32,768
#       BatchNorm3d-40       [-1, 256, 2, 14, 14]             512
#              ReLU-41       [-1, 256, 2, 14, 14]               0
#        BasicBlock-42       [-1, 256, 2, 14, 14]               0
#      Conv3DSimple-43       [-1, 256, 2, 14, 14]       1,769,472
#       BatchNorm3d-44       [-1, 256, 2, 14, 14]             512
#              ReLU-45       [-1, 256, 2, 14, 14]               0
#      Conv3DSimple-46       [-1, 256, 2, 14, 14]       1,769,472
#       BatchNorm3d-47       [-1, 256, 2, 14, 14]             512
#              ReLU-48       [-1, 256, 2, 14, 14]               0
#        BasicBlock-49       [-1, 256, 2, 14, 14]               0
#      Conv3DSimple-50         [-1, 512, 1, 7, 7]       3,538,944
#       BatchNorm3d-51         [-1, 512, 1, 7, 7]           1,024
#              ReLU-52         [-1, 512, 1, 7, 7]               0
#      Conv3DSimple-53         [-1, 512, 1, 7, 7]       7,077,888
#       BatchNorm3d-54         [-1, 512, 1, 7, 7]           1,024
#            Conv3d-55         [-1, 512, 1, 7, 7]         131,072
#       BatchNorm3d-56         [-1, 512, 1, 7, 7]           1,024
#              ReLU-57         [-1, 512, 1, 7, 7]               0
#        BasicBlock-58         [-1, 512, 1, 7, 7]               0
#      Conv3DSimple-59         [-1, 512, 1, 7, 7]       7,077,888
#       BatchNorm3d-60         [-1, 512, 1, 7, 7]           1,024
#              ReLU-61         [-1, 512, 1, 7, 7]               0
#      Conv3DSimple-62         [-1, 512, 1, 7, 7]       7,077,888
#       BatchNorm3d-63         [-1, 512, 1, 7, 7]           1,024
#              ReLU-64         [-1, 512, 1, 7, 7]               0
#        BasicBlock-65         [-1, 512, 1, 7, 7]               0
# AdaptiveAvgPool3d-66         [-1, 512, 1, 1, 1]               0
#            Linear-67                    [-1, 1]             513
#       VideoResNet-68                    [-1, 1]               0
# ================================================================
# Total params: 33,166,785
# Trainable params: 513
# Non-trainable params: 33,166,272
# ----------------------------------------------------------------
# Input size (MB): 0.86
# Forward/backward pass size (MB): 208.25
# Params size (MB): 126.52
# Estimated Total Size (MB): 335.64
# ----------------------------------------------------------------

# %%
# WARM_UP_LR

# %% [markdown]
# ## Training

# %%
losses[:WARM_UP_EPOCHS], val_losses[:WARM_UP_EPOCHS], \
f1_scores[:WARM_UP_EPOCHS], val_f1_scores[:WARM_UP_EPOCHS], \
best_val_loss, \
best_model_state_dict, best_optimizer_state_dict \
= train_the_model(
    model=classifier,
    criterion=criterion,
    optimizer=warmup_optimizer,
    scheduler=warmup_scheduler,
    epochs=WARM_UP_EPOCHS,
    train_dataloader=train_dataloader,
    val_dataloader=val_dataloader,
    best_val_loss=best_val_loss,
)

# Save the best checkpoint.
if best_model_state_dict is not None:
    state = {
        'state_dict': best_model_state_dict,
        'warmup_optimizer': best_optimizer_state_dict,
        'best_val_loss': best_val_loss,
    }
    torch.save(state, 'best-checkout-warmup.pth')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.6080679952634448 | val loss: 0.5835685888810676 | f1: 0.6773163910505836 | val f1: 0.6954407294832827
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.597644759494275 | val loss: 0.5547055150418319 | f1: 0.6875 | val f1: 0.7137993920972644
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.592075538687437 | val loss: 0.5475409926139108 | f1: 0.6895367217898832 | val f1: 0.7251063829787234
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.5932631679604026 | val loss: 0.5520850424329902 | f1: 0.6898407101167315 | val f1: 0.7179331306990883
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.5930137895192618 | val loss: 0.6332532325687334 | f1: 0.6909350680933852 | val f1: 0.6871732522796352

# %%
visualize_results(
    losses=losses[:WARM_UP_EPOCHS],
    val_losses=val_losses[:WARM_UP_EPOCHS],
    f1_scores=f1_scores[:WARM_UP_EPOCHS],
    val_f1_scores=val_f1_scores[:WARM_UP_EPOCHS]
)

# %%
# state = torch.load(PATH2PROJECT / 'trainreface' / 'temp-best-checkout-resnet101.pth', map_location=lambda storage, loc: storage)
state = torch.load('best-checkout-warmup.pth', map_location=lambda storage, loc: storage)
# state = torch.load('best-checkout.pth', map_location=lambda storage, loc: storage)
best_val_loss = state['best_val_loss']
classifier.load_state_dict(state['state_dict'])
# classifier.to(device)
# Out:
# <All keys matched successfully>

# %%
classifier.unfreeze_all_layers()
finetune_optimizer = optim.Adam(filter(lambda p: p.requires_grad, classifier.parameters()), lr=FINE_TUNE_LR)
finetune_scheduler = ReduceLROnPlateau(finetune_optimizer, mode='min', factor=0.1, patience=5, threshold=0.0001, threshold_mode='abs', verbose=True)

# %%
# FINE_TUNE_LR

# %%
# losses[WARM_UP_EPOCHS:WARM_UP_EPOCHS+FINE_TUNE_EPOCHS], val_losses[WARM_UP_EPOCHS:WARM_UP_EPOCHS+FINE_TUNE_EPOCHS], \
# f1_scores[WARM_UP_EPOCHS:WARM_UP_EPOCHS+FINE_TUNE_EPOCHS], val_f1_scores[WARM_UP_EPOCHS:WARM_UP_EPOCHS+FINE_TUNE_EPOCHS], \
# best_val_loss, best_val_logloss, \
# best_model_state_dict, best_optimizer_state_dict \
_, _, \
_, _, \
best_val_loss, \
best_model_state_dict, best_optimizer_state_dict \
= train_the_model(
    model=classifier,
    criterion=criterion,
    optimizer=finetune_optimizer,
    scheduler=finetune_scheduler,
    epochs=FINE_TUNE_EPOCHS,
    train_dataloader=train_dataloader,
    val_dataloader=val_dataloader,
    best_val_loss=best_val_loss,
)

# Save the best checkpoint.
if best_model_state_dict is not None:
    state = {
        'state_dict': best_model_state_dict,
        'finetune_optimizer': best_optimizer_state_dict,
        'best_val_loss': best_val_loss,
    }

    torch.save(state, 'best-checkout-finetune.pth')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.4949396377871473 | val loss: 0.976454612243083 | f1: 0.7612171692607003 | val f1: 0.5804255319148937
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.3611180244325316 | val loss: 0.3158019200660462 | f1: 0.837153453307393 | val f1: 0.8696656534954408
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.3108754902280838 | val loss: 0.23350259595254594 | f1: 0.8686466439688716 | val f1: 0.9061398176291793
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.2788559923723978 | val loss: 0.1723403397860915 | f1: 0.882295719844358 | val f1: 0.9325227963525836
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.25843139145711747 | val loss: 0.18909615067433017 | f1: 0.8913849708171206 | val f1: 0.9240121580547113
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.2441351163429335 | val loss: 0.17559928511984127 | f1: 0.8988630836575877 | val f1: 0.931306990881459
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.22689031683459357 | val loss: 0.17703513107388893 | f1: 0.9068275778210116 | val f1: 0.9311854103343465
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.21554969301164614 | val loss: 0.31339225993137954 | f1: 0.9118433852140078 | val f1: 0.8689361702127659
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.20057910227430586 | val loss: 0.16098786423762523 | f1: 0.9193518968871596 | val f1: 0.9354407294832827
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.19119853173755835 | val loss: 0.1507762093169167 | f1: 0.9230605544747081 | val f1: 0.9418844984802431
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.18404235578493616 | val loss: 0.1307568906828068 | f1: 0.926039640077821 | val f1: 0.9525835866261398
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.17257119345764996 | val loss: 0.16928535881416165 | f1: 0.9300826848249028 | val f1: 0.9343465045592705
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.16810174103362435 | val loss: 0.1435557665554229 | f1: 0.9330009727626459 | val f1: 0.9450455927051672
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.16224973337318938 | val loss: 0.17565543280712279 | f1: 0.9344905155642024 | val f1: 0.931063829787234
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.1570426228706243 | val loss: 0.14413148704433432 | f1: 0.9377127918287937 | val f1: 0.945531914893617
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.15028273641831216 | val loss: 0.1480234576851245 | f1: 0.9417558365758755 | val f1: 0.9418844984802431
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.1432899129721934 | val loss: 0.13324951220939094 | f1: 0.9441877431906615 | val f1: 0.9500303951367781
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.10206191840849758 | val loss: 0.09440930663470844 | f1: 0.9608463035019456 | val f1: 0.9657142857142856
# Found a better checkpoint!
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.08566877255483497 | val loss: 0.09462080528786362 | f1: 0.9686588035019456 | val f1: 0.9680243161094225
#   0%|          | 0/1028 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss: 0.08124265275806812 | val loss: 0.09047357170831759 | f1: 0.9703307392996109 | val f1: 0.969726443768997
# Found a better checkpoint!

# %%
# state = torch.load(PATH2PROJECT / 'trainreface' / 'temp-best-checkout-resnet101.pth', map_location=lambda storage, loc: storage)
state = torch.load('best-checkout-finetune.pth', map_location=lambda storage, loc: storage)
# state = torch.load('best-checkout.pth', map_location=lambda storage, loc: storage)
best_val_loss = state['best_val_loss']
classifier.load_state_dict(state['state_dict'])
# classifier.to(device)
# Out:
# <All keys matched successfully>

# %%
# from IPython.display import FileLink
# FileLink('best-checkout.pth')

# %%
# visualize_results(
#     losses=losses,
#     val_losses=val_losses,
#     loglosses=loglosses,
#     val_loglosses=val_loglosses,
#     f1_scores=f1_scores,
#     val_f1_scores=val_f1_scores
# )

# %% [markdown]
# ## Inference and submission

# %%
def inference(classifier, test_dataloader):
    classifier.eval()
    
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for _, batch in enumerate(tqdm(test_dataloader, total=len(test_dataloader))):
            # Make prediction.
            y_pred = classifier(batch['faces'].to(device))

            all_preds.extend(y_pred.squeeze(dim=-1).detach().cpu().numpy().tolist())
            all_labels.extend(batch['label'].squeeze(dim=-1).numpy().tolist())
    return all_preds, all_labels

# %%
test_prediction, _ = inference(classifier, test_dataloader)
len(test_prediction)
# Out:
#   0%|          | 0/556 [00:00<?, ?it/s]
# 17791

# %%
val_prediction, val_labels = inference(classifier, val_dataloader)
len(val_prediction)
# Out:
#   0%|          | 0/258 [00:00<?, ?it/s]
# 8225

# %%
X_test['score'] = test_prediction

# %%
thresholds = np.linspace(0, 1, len(np.unique(val_prediction)))
f1_scores = [f1_score(val_labels, (np.array(val_prediction) > t).astype(np.uint8), average='micro') for t in tqdm(thresholds)]
t_best = thresholds[np.argmax(f1_scores)]
print('Best threshold: ', t_best)
print('Best F1-Score: ', np.max(f1_scores))
# Out:
#   0%|          | 0/7564 [00:00<?, ?it/s]
# Best threshold:  0.614438714795716
# Best F1-Score:  0.969726443768997

# %%
from IPython.display import FileLink

# %%
X_test['label'] = (X_test['score'] > t_best).astype(int)
submission_result = submission[['filename', 'path']].merge(X_test[['path', 'label']], on='path', how='left').fillna(0)[['filename', 'label']]
submission_result['label'] = submission_result['label'].astype(int)

assert submission_result.shape[0] == submission.shape[0]

submission_result.to_csv('submission_result_th.csv', index=False)

FileLink('submission_result_th.csv')
# Out:
# /content/submission_result_th.csv

# %%
X_test['label'] = (X_test['score'] > 0.5).astype(int)
submission_result = submission[['filename', 'path']].merge(X_test[['path', 'label']], on='path', how='left').fillna(0)[['filename', 'label']]
submission_result['label'] = submission_result['label'].astype(int)

assert submission_result.shape[0] == submission.shape[0]

submission_result.to_csv('submission_result_05.csv', index=False)

FileLink('submission_result_05.csv')
# Out:
# /content/submission_result_05.csv

# %%
# !cp submission_result_th.csv /content/drive/MyDrive/dl-creator-school/submission_result_th.csv

# %%
# !cp submission_result_05.csv /content/drive/MyDrive/dl-creator-school/submission_result_05.csv

# %%
# !cp best-checkout-finetune.pth /content/drive/MyDrive/dl-creator-school/best-checkout-finetune.pth
