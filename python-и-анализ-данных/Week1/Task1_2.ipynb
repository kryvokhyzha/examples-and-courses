# %%
import numpy
numpy.__version__
# Out:
# '1.13.1'

# %%
import scipy
scipy.__version__
# Out:
# '0.19.1'

# %%
import pandas
pandas.__version__
# Out:
# '0.20.3'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.0.2'

# %%
import seaborn
seaborn.__version__
# Out:
# '0.8.0'

# %%
import sklearn
sklearn.__version__
# Out:
# '0.19.0'
